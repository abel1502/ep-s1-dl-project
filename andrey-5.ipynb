# %%
#!pip install emoji catboost

# %%
from __future__ import annotations
import typing
import json
import pathlib
import os
import time
import datetime

import numpy as np
import pandas as pd

from nltk.corpus import stopwords
import emoji

import sklearn
from sklearn.decomposition import PCA
from sklearn.model_selection import train_test_split

import catboost

from tqdm import tqdm

import IPython
from IPython.display import display

# %%
IS_KAGGLE = "KAGGLE_DOCKER_IMAGE" in os.environ

DATASETS = pathlib.Path(
    "."
    if not IS_KAGGLE
    else "/kaggle/input/influencers-or-observers-predicting-social-roles/Kaggle2025"
)

DATASET_TRAIN = DATASETS / "train.jsonl"
DATASET_KAGGLE = DATASETS / "kaggle_test.jsonl"

CACHE_DIR = pathlib.Path(".")

# %%
np.random.seed(42)

# %% [markdown]
# # Data loading

# %%
def load_json(path: pathlib.Path, cache: bool = False) -> pd.DataFrame:
    path_pq = (CACHE_DIR / path.name).with_stem(f"{path.stem}_raw").with_suffix(".parquet")
    
    if cache and path_pq.exists():
        return pd.read_parquet(path_pq)
    
    # This leaves things to be desired, since there's no way to specify dtypes
    # and it assumes float instead of int, causing a loss in precision...
    # But I guess it only matters for ids, which we'll probably discard in preprocessing anyway
    result = pd.json_normalize(list(map(json.loads, path.read_bytes().splitlines())))
    
    if cache:
        result.to_parquet(path_pq)
    
    return result

# %%
train_data = load_json(DATASET_TRAIN, cache=True)
kaggle_data = load_json(DATASET_KAGGLE, cache=True)

# %% [markdown]
# # Preprocessing

# %%
def preprocess(df: pd.DataFrame) -> pd.DataFrame:
    # For technical reasons, any text columns we want to use should have no dots in their names.
    # The simplest way to achieve this is to replace all dots indiscriminately.
    
    df = df.rename(columns=lambda x: x.replace(".", "_"))
    
    df["is_reply"] = df["in_reply_to_status_id"].notna()
    
    df = df.drop(columns=[
        "in_reply_to_status_id_str",
        # "in_reply_to_status_id",
        "in_reply_to_user_id_str",
        "in_reply_to_user_id",
        "quoted_status_id_str",
        "quoted_status_id",
        "id_str",
        "quoted_status_in_reply_to_status_id_str",
        "quoted_status_in_reply_to_status_id",
        "quoted_status_in_reply_to_user_id_str",
        "quoted_status_in_reply_to_user_id",
        "quoted_status_id_str",
        "quoted_status_id",
        "quoted_status_user_id_str",
        "quoted_status_user_id",
        # "quoted_status_permalink_expanded",
        "quoted_status_permalink_display",
        "quoted_status_permalink_url",
        "quoted_status_quoted_status_id",
        "quoted_status_quoted_status_id_str",
        # "quoted_status_place_id",
        # "place_id",
        "lang",  # Always "fr"
        "retweeted",  # Always False
        "filter_level",  # Always "low"
        "geo",  # Always None
        "place",  # Always None
        "coordinates",  # Always None
        "contributors",  # Always None
        "quote_count",  # Always 0
        "reply_count",  # Always 0
        "retweet_count",  # Always 0
        "favorite_count",  # Always 0
        "favorited",  # Always False
        "quoted_status_geo",  # Always None
        "quoted_status_place",  # Always None
        "quoted_status_coordinates",  # Always None
        "quoted_status_retweeted",  # Always False
        "quoted_status_filter_level",  # Always "low"
        "quoted_status_contributors",  # Always None
        "quoted_status_user_utc_offset",  # Always None
        "quoted_status_user_lang",  # Always None
        "quoted_status_user_time_zone",  # Always None
        "quoted_status_user_follow_request_sent",  # Always None
        "quoted_status_user_following",  # Always None
        "quoted_status_user_notifications",  # Always None
        "user_default_profile_image",  # Always False
        "user_protected",  # Always False
        "user_contributors_enabled",  # Always False
        "user_lang",  # Always None
        "user_notifications",  # Always None
        "user_following",  # Always None
        "user_utc_offset",  # Always None
        "user_time_zone",  # Always None
        "user_follow_request_sent",  # Always None
    ])
    
    df["full_text"] = df.apply(lambda tweet: extract_full_text(tweet), axis=1)
    
    source_split = df["source"].str.removeprefix("<a href=\"").str.removesuffix("</a>").str.split("\" rel=\"nofollow\">").map(lambda x: x if len(x) == 2 else pd.NA)
    df["source_url"] = source_split.map(lambda x: x[0], na_action="ignore")
    df["source_name"] = source_split.map(lambda x: x[1], na_action="ignore")
    
    df["misc_text"] = df.apply(
        lambda x: "via: {0}; reply: @{1}; quote: @{2} {3}".format(x["source_name"], x["in_reply_to_screen_name"], x["quoted_status_user_screen_name"], x["quoted_status_user_name"]), axis=1,
    )
    
    dt_cols = ["created_at", "quoted_status_created_at", "quoted_status_user_created_at", "user_created_at"]
    df[dt_cols] = df[dt_cols].apply(pd.to_datetime, format="%a %b %d %H:%M:%S %z %Y", errors="coerce").map(pd.Timestamp.timestamp, na_action="ignore")
    
    return df


def extract_full_text(tweet: pd.Series) -> str:
    text: str = tweet["text"]
    
    if not pd.isna(tweet["extended_tweet_full_text"]):
        text = tweet["extended_tweet_full_text"]
    
    return text

# %%
X_train_pre = train_data.drop("label", axis=1)
y_train = train_data["label"]

X_kaggle_pre = kaggle_data

X_train_pre = preprocess(X_train_pre)
X_kaggle_pre = preprocess(X_kaggle_pre)

# %%
inferred_dtypes = pd.Series({
    col: X_train_pre[col].dropna().convert_dtypes().dtype
    for col in X_train_pre.columns
})
# Out:
# c:\Program Files\Python310\lib\site-packages\pandas\core\dtypes\cast.py:1056: RuntimeWarning: invalid value encountered in cast
#   if (arr.astype(int) == arr).all():
# c:\Program Files\Python310\lib\site-packages\pandas\core\dtypes\cast.py:1080: RuntimeWarning: invalid value encountered in cast
#   if (arr.astype(int) == arr).all():

# %%
with pd.option_context("display.max_rows", None, "display.max_columns", None):
    display(inferred_dtypes)
# Out:
# in_reply_to_status_id                                           Float64
# created_at                                                        Int64
# source                                                   string[python]
# in_reply_to_screen_name                                  string[python]
# is_quote_status                                                 boolean
# text                                                     string[python]
# truncated                                                       boolean
# timestamp_ms                                             string[python]
# challenge_id                                                      Int64
# quoted_status_extended_tweet_entities_urls                       object
# quoted_status_extended_tweet_entities_hashtags                   object
# quoted_status_extended_tweet_entities_user_mentions              object
# quoted_status_extended_tweet_entities_symbols                    object
# quoted_status_extended_tweet_full_text                   string[python]
# quoted_status_extended_tweet_display_text_range                  object
# quoted_status_created_at                                          Int64
# quoted_status_source                                     string[python]
# quoted_status_retweet_count                                       Int64
# quoted_status_in_reply_to_screen_name                    string[python]
# quoted_status_is_quote_status                                   boolean
# quoted_status_favorite_count                                      Int64
# quoted_status_text                                       string[python]
# quoted_status_lang                                       string[python]
# quoted_status_quote_count                                         Int64
# quoted_status_favorited                                         boolean
# quoted_status_truncated                                         boolean
# quoted_status_reply_count                                         Int64
# quoted_status_entities_urls                                      object
# quoted_status_entities_hashtags                                  object
# quoted_status_entities_user_mentions                             object
# quoted_status_entities_symbols                                   object
# quoted_status_user_friends_count                                  Int64
# quoted_status_user_profile_image_url_https               string[python]
# quoted_status_user_listed_count                                   Int64
# quoted_status_user_profile_background_image_url          string[python]
# quoted_status_user_default_profile_image                        boolean
# quoted_status_user_favourites_count                               Int64
# quoted_status_user_description                           string[python]
# quoted_status_user_created_at                                     Int64
# quoted_status_user_is_translator                                boolean
# quoted_status_user_profile_background_image_url_https    string[python]
# quoted_status_user_protected                                    boolean
# quoted_status_user_screen_name                           string[python]
# quoted_status_user_profile_link_color                    string[python]
# quoted_status_user_translator_type                       string[python]
# quoted_status_user_geo_enabled                                  boolean
# quoted_status_user_profile_background_color              string[python]
# quoted_status_user_profile_sidebar_border_color          string[python]
# quoted_status_user_profile_text_color                    string[python]
# quoted_status_user_verified                                     boolean
# quoted_status_user_profile_image_url                     string[python]
# quoted_status_user_url                                   string[python]
# quoted_status_user_contributors_enabled                         boolean
# quoted_status_user_profile_background_tile                      boolean
# quoted_status_user_profile_banner_url                    string[python]
# quoted_status_user_statuses_count                                 Int64
# quoted_status_user_followers_count                                Int64
# quoted_status_user_profile_use_background_image                 boolean
# quoted_status_user_default_profile                              boolean
# quoted_status_user_name                                  string[python]
# quoted_status_user_location                              string[python]
# quoted_status_user_profile_sidebar_fill_color            string[python]
# quoted_status_permalink_expanded                         string[python]
# entities_urls                                                    object
# entities_hashtags                                                object
# entities_user_mentions                                           object
# entities_symbols                                                 object
# user_profile_image_url_https                             string[python]
# user_listed_count                                                 Int64
# user_profile_background_image_url                        string[python]
# user_favourites_count                                             Int64
# user_description                                         string[python]
# user_created_at                                                   Int64
# user_is_translator                                              boolean
# user_profile_background_image_url_https                  string[python]
# user_profile_link_color                                  string[python]
# user_translator_type                                     string[python]
# user_geo_enabled                                                boolean
# user_profile_background_color                            string[python]
# user_profile_sidebar_border_color                        string[python]
# user_profile_text_color                                  string[python]
# user_profile_image_url                                   string[python]
# user_url                                                 string[python]
# user_profile_background_tile                                    boolean
# user_profile_banner_url                                  string[python]
# user_statuses_count                                               Int64
# user_profile_use_background_image                               boolean
# user_default_profile                                            boolean
# user_location                                            string[python]
# user_profile_sidebar_fill_color                          string[python]
# display_text_range                                               object
# extended_tweet_entities_urls                                     object
# extended_tweet_entities_hashtags                                 object
# extended_tweet_entities_user_mentions                            object
# extended_tweet_entities_symbols                                  object
# extended_tweet_full_text                                 string[python]
# extended_tweet_display_text_range                                object
# possibly_sensitive                                              boolean
# quoted_status_possibly_sensitive                                boolean
# quoted_status_extended_entities_media                            object
# quoted_status_entities_media                                     object
# quoted_status_display_text_range                                 object
# extended_tweet_extended_entities_media                           object
# extended_tweet_entities_media                                    object
# quoted_status_extended_tweet_extended_entities_media             object
# quoted_status_extended_tweet_entities_media                      object
# place_country_code                                       string[python]
# place_country                                            string[python]
# place_full_name                                          string[python]
# place_bounding_box_coordinates                                   object
# place_bounding_box_type                                  string[python]
# place_place_type                                         string[python]
# place_name                                               string[python]
# place_id                                                 string[python]
# place_url                                                string[python]
# extended_entities_media                                          object
# entities_media                                                   object
# quoted_status_place_country_code                         string[python]
# quoted_status_place_country                              string[python]
# quoted_status_place_full_name                            string[python]
# quoted_status_place_bounding_box_coordinates                     object
# quoted_status_place_bounding_box_type                    string[python]
# quoted_status_place_place_type                           string[python]
# quoted_status_place_name                                 string[python]
# quoted_status_place_id                                   string[python]
# quoted_status_place_url                                  string[python]
# quoted_status_scopes_followers                                  boolean
# quoted_status_geo_coordinates                                    object
# quoted_status_geo_type                                   string[python]
# quoted_status_coordinates_coordinates                            object
# quoted_status_coordinates_type                           string[python]
# geo_coordinates                                                  object
# geo_type                                                 string[python]
# coordinates_coordinates                                          object
# coordinates_type                                         string[python]
# withheld_in_countries                                            object
# quoted_status_withheld_in_countries                              object
# is_reply                                                        boolean
# full_text                                                string[python]
# source_url                                               string[python]
# source_name                                              string[python]
# misc_text                                                string[python]
# dtype: object

# %%
column_kinds: dict[str, typing.Literal["unknown", "num", "bool", "text", "cat", "skip"]] = \
    dict.fromkeys(X_train_pre.columns, "unknown")

def _mark_resolved():
    inferred_dtypes.drop([k for k, v in column_kinds.items() if v != "unknown"], axis=0, errors="ignore", inplace=True)

# %%
column_kinds["challenge_id"] = "skip"
_mark_resolved()

# %%
print("Inferring kind as num for:")
for col in inferred_dtypes[(inferred_dtypes == "Int64") | (inferred_dtypes == "Float64")].index:
    print(f"> {col}")
    column_kinds[col] = "num"

_mark_resolved()
# Out:
# Inferring kind as num for:
# > in_reply_to_status_id
# > created_at
# > quoted_status_created_at
# > quoted_status_retweet_count
# > quoted_status_favorite_count
# > quoted_status_quote_count
# > quoted_status_reply_count
# > quoted_status_user_friends_count
# > quoted_status_user_listed_count
# > quoted_status_user_favourites_count
# > quoted_status_user_created_at
# > quoted_status_user_statuses_count
# > quoted_status_user_followers_count
# > user_listed_count
# > user_favourites_count
# > user_created_at
# > user_statuses_count

# %%
print("Inferring kind as bool for:")
for col in inferred_dtypes[inferred_dtypes == "boolean"].index:
    print(f"> {col}")
    column_kinds[col] = "bool"

_mark_resolved()
# Out:
# Inferring kind as bool for:
# > is_quote_status
# > truncated
# > quoted_status_is_quote_status
# > quoted_status_favorited
# > quoted_status_truncated
# > quoted_status_user_default_profile_image
# > quoted_status_user_is_translator
# > quoted_status_user_protected
# > quoted_status_user_geo_enabled
# > quoted_status_user_verified
# > quoted_status_user_contributors_enabled
# > quoted_status_user_profile_background_tile
# > quoted_status_user_profile_use_background_image
# > quoted_status_user_default_profile
# > user_is_translator
# > user_geo_enabled
# > user_profile_background_tile
# > user_profile_use_background_image
# > user_default_profile
# > possibly_sensitive
# > quoted_status_possibly_sensitive
# > quoted_status_scopes_followers
# > is_reply

# %%
list_like_cols: list[str] = [
    col
    for col in inferred_dtypes.index
    if X_train_pre[col].map(lambda x: isinstance(x, np.ndarray), na_action="ignore").all()
]

# %%
print("Inferring kind as skip for:")
for col in list_like_cols:
    # # Variable-length lists
    # if X_train[col].dropna().map(len).unique().size > 2:
    print(f"> {col}")
    column_kinds[col] = "skip"

_mark_resolved()

# TODO: Split fixed-length list columns, aka the following, into separate scalar columns:
# tuple_cols = [
#     "coordinates_coordinates",
#     "display_text_range",
#     "entities_media",
#     "extended_tweet_display_text_range",
#     "geo_coordinates",
#     "place_bounding_box_coordinates",
#     "quoted_status_coordinates_coordinates",
#     "quoted_status_display_text_range",
#     "quoted_status_entities_media",
#     "quoted_status_extended_tweet_display_text_range",
#     "quoted_status_geo_coordinates",
#     "quoted_status_place_bounding_box_coordinates",
#     "quoted_status_withheld_in_countries",
#     "withheld_in_countries",
# ]
# Out:
# Inferring kind as skip for:
# > quoted_status_extended_tweet_entities_urls
# > quoted_status_extended_tweet_entities_hashtags
# > quoted_status_extended_tweet_entities_user_mentions
# > quoted_status_extended_tweet_entities_symbols
# > quoted_status_extended_tweet_display_text_range
# > quoted_status_entities_urls
# > quoted_status_entities_hashtags
# > quoted_status_entities_user_mentions
# > quoted_status_entities_symbols
# > entities_urls
# > entities_hashtags
# > entities_user_mentions
# > entities_symbols
# > display_text_range
# > extended_tweet_entities_urls
# > extended_tweet_entities_hashtags
# > extended_tweet_entities_user_mentions
# > extended_tweet_entities_symbols
# > extended_tweet_display_text_range
# > quoted_status_extended_entities_media
# > quoted_status_entities_media
# > quoted_status_display_text_range
# > extended_tweet_extended_entities_media
# > extended_tweet_entities_media
# > quoted_status_extended_tweet_extended_entities_media
# > quoted_status_extended_tweet_entities_media
# > place_bounding_box_coordinates
# > extended_entities_media
# > entities_media
# > quoted_status_place_bounding_box_coordinates
# > quoted_status_geo_coordinates
# > quoted_status_coordinates_coordinates
# > geo_coordinates
# > coordinates_coordinates
# > withheld_in_countries
# > quoted_status_withheld_in_countries

# %%
print("Inferring kind as cat for:")
for col in inferred_dtypes.index:
    if col.endswith("_type") or col.endswith("_kind"):
        print(f"> {col}")
        column_kinds[col] = "cat"

_mark_resolved()
# Out:
# Inferring kind as cat for:
# > quoted_status_user_translator_type
# > user_translator_type
# > place_bounding_box_type
# > place_place_type
# > quoted_status_place_bounding_box_type
# > quoted_status_place_place_type
# > quoted_status_geo_type
# > quoted_status_coordinates_type
# > geo_type
# > coordinates_type

# %%
print("Inferring kind as text for:")
for col in inferred_dtypes[inferred_dtypes == "string[python]"].index:
    print(f"> {col}")
    column_kinds[col] = "text"

_mark_resolved()
# Out:
# Inferring kind as text for:
# > source
# > in_reply_to_screen_name
# > text
# > timestamp_ms
# > quoted_status_extended_tweet_full_text
# > quoted_status_source
# > quoted_status_in_reply_to_screen_name
# > quoted_status_text
# > quoted_status_lang
# > quoted_status_user_profile_image_url_https
# > quoted_status_user_profile_background_image_url
# > quoted_status_user_description
# > quoted_status_user_profile_background_image_url_https
# > quoted_status_user_screen_name
# > quoted_status_user_profile_link_color
# > quoted_status_user_profile_background_color
# > quoted_status_user_profile_sidebar_border_color
# > quoted_status_user_profile_text_color
# > quoted_status_user_profile_image_url
# > quoted_status_user_url
# > quoted_status_user_profile_banner_url
# > quoted_status_user_name
# > quoted_status_user_location
# > quoted_status_user_profile_sidebar_fill_color
# > quoted_status_permalink_expanded
# > user_profile_image_url_https
# > user_profile_background_image_url
# > user_description
# > user_profile_background_image_url_https
# > user_profile_link_color
# > user_profile_background_color
# > user_profile_sidebar_border_color
# > user_profile_text_color
# > user_profile_image_url
# > user_url
# > user_profile_banner_url
# > user_location
# > user_profile_sidebar_fill_color
# > extended_tweet_full_text
# > place_country_code
# > place_country
# > place_full_name
# > place_name
# > place_id
# > place_url
# > quoted_status_place_country_code
# > quoted_status_place_country
# > quoted_status_place_full_name
# > quoted_status_place_name
# > quoted_status_place_id
# > quoted_status_place_url
# > full_text
# > source_url
# > source_name
# > misc_text

# %%
assert len(inferred_dtypes) == 0, "Some columns have not been categorized!"

# %%
column_kinds: pd.Series = pd.Series(column_kinds)

# %%
def preprocess2(df: pd.DataFrame) -> pd.DataFrame:
    skip_cols = list(column_kinds[column_kinds == "skip"].index)
    df = df.drop(columns=skip_cols, errors="ignore")
    
    bool_cols = list(column_kinds[column_kinds == "bool"].index)
    df[bool_cols] = df[bool_cols].map({True: 1, False: -1, None: 0}.__getitem__).astype(int)
    
    cat_cols = list(column_kinds[column_kinds == "cat"].index)
    df[cat_cols] = df[cat_cols].fillna("none").astype(str)
    
    text_cols = list(column_kinds[column_kinds == "text"].index)
    df[text_cols] = df[text_cols].fillna("").astype(str)
    
    num_cols = list(column_kinds[column_kinds == "num"].index)
    df[num_cols] = df[num_cols].fillna(0).convert_dtypes()
    
    return df

# %%
X_train = preprocess2(X_train_pre)
X_kaggle = preprocess2(X_kaggle_pre)
# Out:
# C:\Users\Abel\AppData\Local\Temp\ipykernel_31064\2141908415.py:15: FutureWarning: Downcasting object dtype arrays on .fillna, .ffill, .bfill is deprecated and will change in a future version. Call result.infer_objects(copy=False) instead. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   df[num_cols] = df[num_cols].fillna(0).convert_dtypes()
# c:\Program Files\Python310\lib\site-packages\pandas\core\dtypes\cast.py:1056: RuntimeWarning: invalid value encountered in cast
#   if (arr.astype(int) == arr).all():
# c:\Program Files\Python310\lib\site-packages\pandas\core\dtypes\cast.py:1080: RuntimeWarning: invalid value encountered in cast
#   if (arr.astype(int) == arr).all():
# C:\Users\Abel\AppData\Local\Temp\ipykernel_31064\2141908415.py:15: FutureWarning: Downcasting object dtype arrays on .fillna, .ffill, .bfill is deprecated and will change in a future version. Call result.infer_objects(copy=False) instead. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   df[num_cols] = df[num_cols].fillna(0).convert_dtypes()
# c:\Program Files\Python310\lib\site-packages\pandas\core\dtypes\cast.py:1056: RuntimeWarning: invalid value encountered in cast
#   if (arr.astype(int) == arr).all():
# c:\Program Files\Python310\lib\site-packages\pandas\core\dtypes\cast.py:1080: RuntimeWarning: invalid value encountered in cast
#   if (arr.astype(int) == arr).all():

# %% [markdown]
# # Models

# %%
X_train_for_real, X_val, y_train_for_real, y_val = train_test_split(X_train, y_train, test_size=0.15, random_state=42)

# %%
def make_pool(X, y) -> catboost.Pool:
    num_cols = list(column_kinds[column_kinds == "num"].index)
    cat_cols = list(column_kinds[column_kinds.isin(["cat", "bool"])].index)
    text_cols = list(column_kinds[column_kinds == "text"].index)
    
    X = X[num_cols + cat_cols + text_cols]
    
    return catboost.Pool(
        data=X,
        label=y,
        cat_features=cat_cols,
        text_features=text_cols,
    )

train_pool = make_pool(X_train_for_real, y_train_for_real)
val_pool = make_pool(X_val, y_val)
kaggle_pool = make_pool(X_kaggle, None)

# %%
model = catboost.CatBoostClassifier(
    loss_function="Logloss",
    random_seed=42,
    eval_metric="Accuracy",
    task_type="GPU",
    devices="0",
    # save_snapshot=True,
    # snapshot_interval=300,
    train_dir="./models/v12/gridsearch",
)

param_grid = {
    "depth": [4, 6, 8, 10],
    "learning_rate": [0.05, 0.1],
    "iterations": [1000, 2000],
}

model.grid_search(
    param_grid,
    train_pool,
    verbose=100,
    plot=True,
    plot_file="models/v12/gridsearch/grid_search.info",
)
# Out:
# MetricVisualizer(layout=Layout(align_self='stretch', height='500px'))
# 0:	learn: 0.7984147	test: 0.7995519	best: 0.7995519 (0)	total: 148ms	remaining: 2m 27s
# 1:	learn: 0.8018986	test: 0.8007670	best: 0.8007670 (1)	total: 274ms	remaining: 2m 16s
# 2:	learn: 0.8072432	test: 0.8066145	best: 0.8066145 (2)	total: 359ms	remaining: 1m 59s
# 3:	learn: 0.8074616	test: 0.8077916	best: 0.8077916 (3)	total: 439ms	remaining: 1m 49s
# 4:	learn: 0.8075470	test: 0.8083991	best: 0.8083991 (4)	total: 516ms	remaining: 1m 42s
# 5:	learn: 0.8116670	test: 0.8118165	best: 0.8118165 (5)	total: 607ms	remaining: 1m 40s
# 6:	learn: 0.8118568	test: 0.8121583	best: 0.8121583 (6)	total: 710ms	remaining: 1m 40s
# 7:	learn: 0.8111639	test: 0.8112470	best: 0.8121583 (6)	total: 785ms	remaining: 1m 37s
# 8:	learn: 0.8112778	test: 0.8118165	best: 0.8121583 (6)	total: 859ms	remaining: 1m 34s
# 9:	learn: 0.8117999	test: 0.8118165	best: 0.8121583 (6)	total: 938ms	remaining: 1m 32s
# 10:	learn: 0.8119423	test: 0.8121962	best: 0.8121962 (10)	total: 1.01s	remaining: 1m 30s
# 11:	learn: 0.8125878	test: 0.8110951	best: 0.8121962 (10)	total: 1.11s	remaining: 1m 31s
# 12:	learn: 0.8127492	test: 0.8120064	best: 0.8121962 (10)	total: 1.24s	remaining: 1m 33s
# 13:	learn: 0.8129675	test: 0.8124620	best: 0.8124620 (13)	total: 1.33s	remaining: 1m 34s
# 14:	learn: 0.8134991	test: 0.8128797	best: 0.8128797 (14)	total: 1.44s	remaining: 1m 34s
# 15:	learn: 0.8138979	test: 0.8129936	best: 0.8129936 (15)	total: 1.53s	remaining: 1m 34s
# 16:	learn: 0.8138599	test: 0.8129936	best: 0.8129936 (15)	total: 1.63s	remaining: 1m 34s
# 17:	learn: 0.8143061	test: 0.8128797	best: 0.8129936 (15)	total: 1.72s	remaining: 1m 34s
# 18:	learn: 0.8144959	test: 0.8139809	best: 0.8139809 (18)	total: 1.8s	remaining: 1m 32s
# 19:	learn: 0.8143345	test: 0.8137910	best: 0.8139809 (18)	total: 1.95s	remaining: 1m 35s
# 20:	learn: 0.8144769	test: 0.8124241	best: 0.8139809 (18)	total: 2.08s	remaining: 1m 37s
# 21:	learn: 0.8148756	test: 0.8133354	best: 0.8139809 (18)	total: 2.16s	remaining: 1m 36s
# 22:	learn: 0.8148472	test: 0.8134113	best: 0.8139809 (18)	total: 2.25s	remaining: 1m 35s
# 23:	learn: 0.8154262	test: 0.8137151	best: 0.8139809 (18)	total: 2.34s	remaining: 1m 35s
# 24:	learn: 0.8158914	test: 0.8144745	best: 0.8144745 (24)	total: 2.42s	remaining: 1m 34s
# 25:	learn: 0.8156826	test: 0.8144365	best: 0.8144745 (24)	total: 2.55s	remaining: 1m 35s
# 26:	learn: 0.8160053	test: 0.8141327	best: 0.8144745 (24)	total: 2.64s	remaining: 1m 35s
# 27:	learn: 0.8162711	test: 0.8149681	best: 0.8149681 (27)	total: 2.73s	remaining: 1m 34s
# 28:	learn: 0.8161667	test: 0.8151200	best: 0.8151200 (28)	total: 2.8s	remaining: 1m 33s
# 29:	learn: 0.8163281	test: 0.8150820	best: 0.8151200 (28)	total: 2.88s	remaining: 1m 33s
# 30:	learn: 0.8163281	test: 0.8152339	best: 0.8152339 (30)	total: 2.96s	remaining: 1m 32s
# 31:	learn: 0.8166129	test: 0.8158035	best: 0.8158035 (31)	total: 3.06s	remaining: 1m 32s
# 32:	learn: 0.8170211	test: 0.8164110	best: 0.8164110 (32)	total: 3.2s	remaining: 1m 33s
# 33:	learn: 0.8173723	test: 0.8169426	best: 0.8169426 (33)	total: 3.29s	remaining: 1m 33s
# 34:	learn: 0.8169072	test: 0.8164869	best: 0.8169426 (33)	total: 3.39s	remaining: 1m 33s
# 35:	learn: 0.8171825	test: 0.8172084	best: 0.8172084 (35)	total: 3.49s	remaining: 1m 33s
# 36:	learn: 0.8172489	test: 0.8175501	best: 0.8175501 (36)	total: 3.57s	remaining: 1m 32s
# 37:	learn: 0.8173818	test: 0.8176261	best: 0.8176261 (37)	total: 3.65s	remaining: 1m 32s
# 38:	learn: 0.8178660	test: 0.8176261	best: 0.8176261 (37)	total: 3.77s	remaining: 1m 32s
# 39:	learn: 0.8180368	test: 0.8174742	best: 0.8176261 (37)	total: 3.86s	remaining: 1m 32s
# 40:	learn: 0.8181697	test: 0.8178539	best: 0.8178539 (40)	total: 3.95s	remaining: 1m 32s
# 41:	learn: 0.8184640	test: 0.8182336	best: 0.8182336 (41)	total: 4.03s	remaining: 1m 31s
# 42:	learn: 0.8187583	test: 0.8184994	best: 0.8184994 (42)	total: 4.1s	remaining: 1m 31s
# 43:	learn: 0.8189292	test: 0.8189550	best: 0.8189550 (43)	total: 4.2s	remaining: 1m 31s
# 44:	learn: 0.8191665	test: 0.8195246	best: 0.8195246 (44)	total: 4.29s	remaining: 1m 31s
# 45:	learn: 0.8194608	test: 0.8196765	best: 0.8196765 (45)	total: 4.37s	remaining: 1m 30s
# 46:	learn: 0.8196696	test: 0.8197904	best: 0.8197904 (46)	total: 4.44s	remaining: 1m 30s
# 47:	learn: 0.8197551	test: 0.8199803	best: 0.8199803 (47)	total: 4.52s	remaining: 1m 29s
# 48:	learn: 0.8199544	test: 0.8205118	best: 0.8205118 (48)	total: 4.61s	remaining: 1m 29s
# 49:	learn: 0.8202392	test: 0.8209675	best: 0.8209675 (49)	total: 4.71s	remaining: 1m 29s
# 50:	learn: 0.8204196	test: 0.8211953	best: 0.8211953 (50)	total: 4.79s	remaining: 1m 29s
# 51:	learn: 0.8205620	test: 0.8214991	best: 0.8214991 (51)	total: 4.86s	remaining: 1m 28s
# 52:	learn: 0.8207139	test: 0.8214991	best: 0.8214991 (51)	total: 4.94s	remaining: 1m 28s
# 53:	learn: 0.8210272	test: 0.8217269	best: 0.8217269 (53)	total: 5.02s	remaining: 1m 27s
# 54:	learn: 0.8210746	test: 0.8219927	best: 0.8219927 (54)	total: 5.11s	remaining: 1m 27s
# 55:	learn: 0.8214828	test: 0.8223344	best: 0.8223344 (55)	total: 5.24s	remaining: 1m 28s
# 56:	learn: 0.8216727	test: 0.8224104	best: 0.8224104 (56)	total: 5.4s	remaining: 1m 29s
# 57:	learn: 0.8218436	test: 0.8227521	best: 0.8227521 (57)	total: 5.56s	remaining: 1m 30s
# 58:	learn: 0.8217107	test: 0.8229040	best: 0.8229040 (58)	total: 5.77s	remaining: 1m 32s
# 59:	learn: 0.8217391	test: 0.8229800	best: 0.8229800 (59)	total: 5.91s	remaining: 1m 32s
# 60:	learn: 0.8219765	test: 0.8229040	best: 0.8229800 (59)	total: 6.03s	remaining: 1m 32s
# 61:	learn: 0.8219480	test: 0.8229420	best: 0.8229800 (59)	total: 6.12s	remaining: 1m 32s
# 62:	learn: 0.8221094	test: 0.8230179	best: 0.8230179 (62)	total: 6.25s	remaining: 1m 32s
# 63:	learn: 0.8222897	test: 0.8231318	best: 0.8231318 (63)	total: 6.34s	remaining: 1m 32s
# 64:	learn: 0.8223847	test: 0.8232457	best: 0.8232457 (64)	total: 6.43s	remaining: 1m 32s
# 65:	learn: 0.8224986	test: 0.8234736	best: 0.8234736 (65)	total: 6.53s	remaining: 1m 32s
# 66:	learn: 0.8228403	test: 0.8238153	best: 0.8238153 (66)	total: 6.6s	remaining: 1m 31s
# 67:	learn: 0.8232106	test: 0.8239292	best: 0.8239292 (67)	total: 6.67s	remaining: 1m 31s
# 68:	learn: 0.8232390	test: 0.8244608	best: 0.8244608 (68)	total: 6.75s	remaining: 1m 31s
# 69:	learn: 0.8233624	test: 0.8243469	best: 0.8244608 (68)	total: 6.83s	remaining: 1m 30s
# 70:	learn: 0.8234953	test: 0.8244228	best: 0.8244608 (68)	total: 6.94s	remaining: 1m 30s
# 71:	learn: 0.8236947	test: 0.8242330	best: 0.8244608 (68)	total: 7.01s	remaining: 1m 30s
# 72:	learn: 0.8236567	test: 0.8243089	best: 0.8244608 (68)	total: 7.09s	remaining: 1m 30s
# 73:	learn: 0.8236377	test: 0.8243089	best: 0.8244608 (68)	total: 7.18s	remaining: 1m 29s
# 74:	learn: 0.8236662	test: 0.8243089	best: 0.8244608 (68)	total: 7.25s	remaining: 1m 29s
# 75:	learn: 0.8236947	test: 0.8243089	best: 0.8244608 (68)	total: 7.33s	remaining: 1m 29s
# 76:	learn: 0.8238561	test: 0.8241950	best: 0.8244608 (68)	total: 7.43s	remaining: 1m 29s
# 77:	learn: 0.8239225	test: 0.8243089	best: 0.8244608 (68)	total: 7.52s	remaining: 1m 28s
# 78:	learn: 0.8239225	test: 0.8243849	best: 0.8244608 (68)	total: 7.58s	remaining: 1m 28s
# 79:	learn: 0.8237042	test: 0.8244988	best: 0.8244988 (79)	total: 7.65s	remaining: 1m 28s
# 80:	learn: 0.8238656	test: 0.8247266	best: 0.8247266 (80)	total: 7.72s	remaining: 1m 27s
# 81:	learn: 0.8237991	test: 0.8247266	best: 0.8247266 (80)	total: 7.79s	remaining: 1m 27s
# 82:	learn: 0.8239605	test: 0.8249544	best: 0.8249544 (82)	total: 7.86s	remaining: 1m 26s
# 83:	learn: 0.8242643	test: 0.8249924	best: 0.8249924 (83)	total: 7.92s	remaining: 1m 26s
# 84:	learn: 0.8244257	test: 0.8251823	best: 0.8251823 (84)	total: 7.99s	remaining: 1m 26s
# 85:	learn: 0.8243497	test: 0.8253721	best: 0.8253721 (85)	total: 8.06s	remaining: 1m 25s
# 86:	learn: 0.8243118	test: 0.8254860	best: 0.8254860 (86)	total: 8.13s	remaining: 1m 25s
# 87:	learn: 0.8243307	test: 0.8252202	best: 0.8254860 (86)	total: 8.26s	remaining: 1m 25s
# 88:	learn: 0.8243497	test: 0.8254481	best: 0.8254860 (86)	total: 8.34s	remaining: 1m 25s
# 89:	learn: 0.8243687	test: 0.8252962	best: 0.8254860 (86)	total: 8.43s	remaining: 1m 25s
# 90:	learn: 0.8244352	test: 0.8253721	best: 0.8254860 (86)	total: 8.51s	remaining: 1m 25s
# 91:	learn: 0.8246060	test: 0.8253341	best: 0.8254860 (86)	total: 8.6s	remaining: 1m 24s
# 92:	learn: 0.8246820	test: 0.8252202	best: 0.8254860 (86)	total: 8.67s	remaining: 1m 24s
# 93:	learn: 0.8248339	test: 0.8253721	best: 0.8254860 (86)	total: 8.74s	remaining: 1m 24s
# 94:	learn: 0.8250712	test: 0.8250683	best: 0.8254860 (86)	total: 8.89s	remaining: 1m 24s
# 95:	learn: 0.8249668	test: 0.8255240	best: 0.8255240 (95)	total: 8.97s	remaining: 1m 24s
# 96:	learn: 0.8252326	test: 0.8255240	best: 0.8255240 (95)	total: 9.04s	remaining: 1m 24s
# 97:	learn: 0.8252136	test: 0.8255240	best: 0.8255240 (95)	total: 9.1s	remaining: 1m 23s
# 98:	learn: 0.8251946	test: 0.8255240	best: 0.8255240 (95)	total: 9.18s	remaining: 1m 23s
# 99:	learn: 0.8252800	test: 0.8255240	best: 0.8255240 (95)	total: 9.25s	remaining: 1m 23s
# 100:	learn: 0.8253655	test: 0.8256759	best: 0.8256759 (100)	total: 9.31s	remaining: 1m 22s
# 101:	learn: 0.8255648	test: 0.8255240	best: 0.8256759 (100)	total: 9.39s	remaining: 1m 22s
# 102:	learn: 0.8255079	test: 0.8256759	best: 0.8256759 (100)	total: 9.46s	remaining: 1m 22s
# 103:	learn: 0.8255174	test: 0.8257139	best: 0.8257139 (103)	total: 9.54s	remaining: 1m 22s
# 104:	learn: 0.8254509	test: 0.8259037	best: 0.8259037 (104)	total: 9.61s	remaining: 1m 21s
# 105:	learn: 0.8257072	test: 0.8261315	best: 0.8261315 (105)	total: 9.69s	remaining: 1m 21s
# 106:	learn: 0.8256598	test: 0.8261695	best: 0.8261695 (106)	total: 9.84s	remaining: 1m 22s
# 107:	learn: 0.8257547	test: 0.8260936	best: 0.8261695 (106)	total: 9.91s	remaining: 1m 21s
# 108:	learn: 0.8258686	test: 0.8261315	best: 0.8261695 (106)	total: 9.99s	remaining: 1m 21s
# 109:	learn: 0.8259256	test: 0.8261695	best: 0.8261695 (106)	total: 10.1s	remaining: 1m 21s
# 110:	learn: 0.8260015	test: 0.8262834	best: 0.8262834 (110)	total: 10.2s	remaining: 1m 21s
# 111:	learn: 0.8260870	test: 0.8262454	best: 0.8262834 (110)	total: 10.2s	remaining: 1m 21s
# 112:	learn: 0.8260585	test: 0.8264733	best: 0.8264733 (112)	total: 10.3s	remaining: 1m 20s
# 113:	learn: 0.8260775	test: 0.8260936	best: 0.8264733 (112)	total: 10.4s	remaining: 1m 20s
# 114:	learn: 0.8263433	test: 0.8265492	best: 0.8265492 (114)	total: 10.5s	remaining: 1m 20s
# 115:	learn: 0.8263907	test: 0.8264353	best: 0.8265492 (114)	total: 10.5s	remaining: 1m 20s
# 116:	learn: 0.8263338	test: 0.8265872	best: 0.8265872 (116)	total: 10.6s	remaining: 1m 20s
# 117:	learn: 0.8264572	test: 0.8265492	best: 0.8265872 (116)	total: 10.7s	remaining: 1m 20s
# 118:	learn: 0.8265141	test: 0.8264733	best: 0.8265872 (116)	total: 10.8s	remaining: 1m 19s
# 119:	learn: 0.8265616	test: 0.8263594	best: 0.8265872 (116)	total: 10.9s	remaining: 1m 19s
# 120:	learn: 0.8264572	test: 0.8266252	best: 0.8266252 (120)	total: 11s	remaining: 1m 19s
# 121:	learn: 0.8265711	test: 0.8264733	best: 0.8266252 (120)	total: 11s	remaining: 1m 19s
# 122:	learn: 0.8265901	test: 0.8264733	best: 0.8266252 (120)	total: 11.1s	remaining: 1m 19s
# 123:	learn: 0.8266660	test: 0.8264353	best: 0.8266252 (120)	total: 11.2s	remaining: 1m 19s
# 124:	learn: 0.8267135	test: 0.8263594	best: 0.8266252 (120)	total: 11.3s	remaining: 1m 18s
# 125:	learn: 0.8265806	test: 0.8265112	best: 0.8266252 (120)	total: 11.4s	remaining: 1m 18s
# 126:	learn: 0.8267515	test: 0.8266252	best: 0.8266252 (120)	total: 11.5s	remaining: 1m 18s
# 127:	learn: 0.8267325	test: 0.8267391	best: 0.8267391 (127)	total: 11.6s	remaining: 1m 18s
# 128:	learn: 0.8268749	test: 0.8269289	best: 0.8269289 (128)	total: 11.7s	remaining: 1m 18s
# 129:	learn: 0.8269034	test: 0.8268909	best: 0.8269289 (128)	total: 11.7s	remaining: 1m 18s
# 130:	learn: 0.8268654	test: 0.8268530	best: 0.8269289 (128)	total: 11.8s	remaining: 1m 18s
# 131:	learn: 0.8268369	test: 0.8270049	best: 0.8270049 (131)	total: 11.9s	remaining: 1m 18s
# 132:	learn: 0.8268939	test: 0.8271188	best: 0.8271188 (132)	total: 12s	remaining: 1m 18s
# 133:	learn: 0.8269318	test: 0.8268909	best: 0.8271188 (132)	total: 12.1s	remaining: 1m 18s
# 134:	learn: 0.8269793	test: 0.8270049	best: 0.8271188 (132)	total: 12.2s	remaining: 1m 18s
# 135:	learn: 0.8271692	test: 0.8270808	best: 0.8271188 (132)	total: 12.3s	remaining: 1m 17s
# 136:	learn: 0.8273021	test: 0.8270049	best: 0.8271188 (132)	total: 12.3s	remaining: 1m 17s
# 137:	learn: 0.8273116	test: 0.8269669	best: 0.8271188 (132)	total: 12.4s	remaining: 1m 17s
# 138:	learn: 0.8273780	test: 0.8268530	best: 0.8271188 (132)	total: 12.5s	remaining: 1m 17s
# 139:	learn: 0.8274255	test: 0.8268150	best: 0.8271188 (132)	total: 12.6s	remaining: 1m 17s
# 140:	learn: 0.8273970	test: 0.8269289	best: 0.8271188 (132)	total: 12.7s	remaining: 1m 17s
# 141:	learn: 0.8275394	test: 0.8268909	best: 0.8271188 (132)	total: 12.7s	remaining: 1m 16s
# 142:	learn: 0.8275394	test: 0.8270049	best: 0.8271188 (132)	total: 12.8s	remaining: 1m 16s
# 143:	learn: 0.8275489	test: 0.8270428	best: 0.8271188 (132)	total: 12.9s	remaining: 1m 16s
# 144:	learn: 0.8276058	test: 0.8273086	best: 0.8273086 (144)	total: 13s	remaining: 1m 16s
# 145:	learn: 0.8276628	test: 0.8271947	best: 0.8273086 (144)	total: 13.1s	remaining: 1m 16s
# 146:	learn: 0.8277672	test: 0.8269289	best: 0.8273086 (144)	total: 13.1s	remaining: 1m 16s
# 147:	learn: 0.8277388	test: 0.8268909	best: 0.8273086 (144)	total: 13.2s	remaining: 1m 16s
# 148:	learn: 0.8277577	test: 0.8268909	best: 0.8273086 (144)	total: 13.3s	remaining: 1m 16s
# 149:	learn: 0.8279001	test: 0.8272327	best: 0.8273086 (144)	total: 13.4s	remaining: 1m 16s
# 150:	learn: 0.8279191	test: 0.8273086	best: 0.8273086 (144)	total: 13.5s	remaining: 1m 15s
# 151:	learn: 0.8280805	test: 0.8274225	best: 0.8274225 (151)	total: 13.6s	remaining: 1m 15s
# 152:	learn: 0.8281564	test: 0.8274605	best: 0.8274605 (152)	total: 13.6s	remaining: 1m 15s
# 153:	learn: 0.8281754	test: 0.8275744	best: 0.8275744 (153)	total: 13.7s	remaining: 1m 15s
# 154:	learn: 0.8283368	test: 0.8276124	best: 0.8276124 (154)	total: 13.8s	remaining: 1m 15s
# 155:	learn: 0.8285457	test: 0.8275744	best: 0.8276124 (154)	total: 13.9s	remaining: 1m 15s
# 156:	learn: 0.8283938	test: 0.8279541	best: 0.8279541 (156)	total: 14s	remaining: 1m 15s
# 157:	learn: 0.8284602	test: 0.8278782	best: 0.8279541 (156)	total: 14.1s	remaining: 1m 14s
# 158:	learn: 0.8284792	test: 0.8278402	best: 0.8279541 (156)	total: 14.2s	remaining: 1m 14s
# 159:	learn: 0.8285077	test: 0.8278782	best: 0.8279541 (156)	total: 14.2s	remaining: 1m 14s
# 160:	learn: 0.8283558	test: 0.8282579	best: 0.8282579 (160)	total: 14.3s	remaining: 1m 14s
# 161:	learn: 0.8283843	test: 0.8281060	best: 0.8282579 (160)	total: 14.4s	remaining: 1m 14s
# 162:	learn: 0.8286026	test: 0.8281440	best: 0.8282579 (160)	total: 14.6s	remaining: 1m 14s
# 163:	learn: 0.8285931	test: 0.8281820	best: 0.8282579 (160)	total: 14.7s	remaining: 1m 14s
# 164:	learn: 0.8286311	test: 0.8281440	best: 0.8282579 (160)	total: 14.7s	remaining: 1m 14s
# 165:	learn: 0.8285077	test: 0.8280301	best: 0.8282579 (160)	total: 14.8s	remaining: 1m 14s
# 166:	learn: 0.8285741	test: 0.8281440	best: 0.8282579 (160)	total: 14.9s	remaining: 1m 14s
# 167:	learn: 0.8286311	test: 0.8282579	best: 0.8282579 (160)	total: 15s	remaining: 1m 14s
# 168:	learn: 0.8286406	test: 0.8281440	best: 0.8282579 (160)	total: 15s	remaining: 1m 13s
# 169:	learn: 0.8286596	test: 0.8280301	best: 0.8282579 (160)	total: 15.1s	remaining: 1m 13s
# 170:	learn: 0.8286691	test: 0.8281820	best: 0.8282579 (160)	total: 15.3s	remaining: 1m 14s
# 171:	learn: 0.8287070	test: 0.8278022	best: 0.8282579 (160)	total: 15.4s	remaining: 1m 14s
# 172:	learn: 0.8286121	test: 0.8279162	best: 0.8282579 (160)	total: 15.4s	remaining: 1m 13s
# 173:	learn: 0.8285741	test: 0.8279162	best: 0.8282579 (160)	total: 15.5s	remaining: 1m 13s
# 174:	learn: 0.8285836	test: 0.8279541	best: 0.8282579 (160)	total: 15.6s	remaining: 1m 13s
# 175:	learn: 0.8287450	test: 0.8278782	best: 0.8282579 (160)	total: 15.7s	remaining: 1m 13s
# 176:	learn: 0.8288494	test: 0.8279162	best: 0.8282579 (160)	total: 15.8s	remaining: 1m 13s
# 177:	learn: 0.8288399	test: 0.8280301	best: 0.8282579 (160)	total: 15.8s	remaining: 1m 13s
# 178:	learn: 0.8288969	test: 0.8281440	best: 0.8282579 (160)	total: 15.9s	remaining: 1m 13s
# 179:	learn: 0.8289634	test: 0.8281440	best: 0.8282579 (160)	total: 16s	remaining: 1m 12s
# 180:	learn: 0.8289539	test: 0.8279541	best: 0.8282579 (160)	total: 16.1s	remaining: 1m 12s
# 181:	learn: 0.8290298	test: 0.8278782	best: 0.8282579 (160)	total: 16.2s	remaining: 1m 12s
# 182:	learn: 0.8290393	test: 0.8280301	best: 0.8282579 (160)	total: 16.3s	remaining: 1m 12s
# 183:	learn: 0.8290298	test: 0.8281060	best: 0.8282579 (160)	total: 16.3s	remaining: 1m 12s
# 184:	learn: 0.8290393	test: 0.8281060	best: 0.8282579 (160)	total: 16.5s	remaining: 1m 12s
# 185:	learn: 0.8290203	test: 0.8282199	best: 0.8282579 (160)	total: 16.6s	remaining: 1m 12s
# 186:	learn: 0.8291152	test: 0.8282199	best: 0.8282579 (160)	total: 16.6s	remaining: 1m 12s
# 187:	learn: 0.8292481	test: 0.8282199	best: 0.8282579 (160)	total: 16.7s	remaining: 1m 12s
# 188:	learn: 0.8293336	test: 0.8283718	best: 0.8283718 (188)	total: 16.8s	remaining: 1m 12s
# 189:	learn: 0.8292671	test: 0.8283338	best: 0.8283718 (188)	total: 16.9s	remaining: 1m 12s
# 190:	learn: 0.8292197	test: 0.8284478	best: 0.8284478 (190)	total: 17s	remaining: 1m 12s
# 191:	learn: 0.8292671	test: 0.8283718	best: 0.8284478 (190)	total: 17.1s	remaining: 1m 11s
# 192:	learn: 0.8292292	test: 0.8286376	best: 0.8286376 (192)	total: 17.2s	remaining: 1m 11s
# 193:	learn: 0.8292766	test: 0.8287895	best: 0.8287895 (193)	total: 17.2s	remaining: 1m 11s
# 194:	learn: 0.8293811	test: 0.8288275	best: 0.8288275 (194)	total: 17.3s	remaining: 1m 11s
# 195:	learn: 0.8294570	test: 0.8287515	best: 0.8288275 (194)	total: 17.4s	remaining: 1m 11s
# 196:	learn: 0.8293431	test: 0.8287895	best: 0.8288275 (194)	total: 17.5s	remaining: 1m 11s
# 197:	learn: 0.8293431	test: 0.8289414	best: 0.8289414 (197)	total: 17.6s	remaining: 1m 11s
# 198:	learn: 0.8293905	test: 0.8287895	best: 0.8289414 (197)	total: 17.7s	remaining: 1m 11s
# 199:	learn: 0.8293431	test: 0.8287135	best: 0.8289414 (197)	total: 17.8s	remaining: 1m 11s
# 200:	learn: 0.8294095	test: 0.8288654	best: 0.8289414 (197)	total: 17.8s	remaining: 1m 10s
# 201:	learn: 0.8294760	test: 0.8286756	best: 0.8289414 (197)	total: 17.9s	remaining: 1m 10s
# 202:	learn: 0.8295329	test: 0.8287895	best: 0.8289414 (197)	total: 18.1s	remaining: 1m 10s
# 203:	learn: 0.8294000	test: 0.8287515	best: 0.8289414 (197)	total: 18.2s	remaining: 1m 10s
# 204:	learn: 0.8294760	test: 0.8289414	best: 0.8289414 (197)	total: 18.2s	remaining: 1m 10s
# 205:	learn: 0.8294570	test: 0.8289793	best: 0.8289793 (205)	total: 18.3s	remaining: 1m 10s
# 206:	learn: 0.8294570	test: 0.8289034	best: 0.8289793 (205)	total: 18.4s	remaining: 1m 10s
# 207:	learn: 0.8295614	test: 0.8288275	best: 0.8289793 (205)	total: 18.5s	remaining: 1m 10s
# 208:	learn: 0.8295994	test: 0.8289414	best: 0.8289793 (205)	total: 18.5s	remaining: 1m 10s
# 209:	learn: 0.8297133	test: 0.8290173	best: 0.8290173 (209)	total: 18.6s	remaining: 1m 10s
# 210:	learn: 0.8298082	test: 0.8289793	best: 0.8290173 (209)	total: 18.7s	remaining: 1m 9s
# 211:	learn: 0.8298082	test: 0.8290933	best: 0.8290933 (211)	total: 18.8s	remaining: 1m 9s
# 212:	learn: 0.8298462	test: 0.8290933	best: 0.8290933 (211)	total: 18.9s	remaining: 1m 9s
# 213:	learn: 0.8299411	test: 0.8290933	best: 0.8290933 (211)	total: 18.9s	remaining: 1m 9s
# 214:	learn: 0.8299601	test: 0.8290933	best: 0.8290933 (211)	total: 19s	remaining: 1m 9s
# 215:	learn: 0.8299316	test: 0.8292072	best: 0.8292072 (215)	total: 19.1s	remaining: 1m 9s
# 216:	learn: 0.8300076	test: 0.8292451	best: 0.8292451 (216)	total: 19.2s	remaining: 1m 9s
# 217:	learn: 0.8300361	test: 0.8292831	best: 0.8292831 (217)	total: 19.3s	remaining: 1m 9s
# 218:	learn: 0.8301405	test: 0.8291692	best: 0.8292831 (217)	total: 19.4s	remaining: 1m 9s
# 219:	learn: 0.8302354	test: 0.8293591	best: 0.8293591 (219)	total: 19.5s	remaining: 1m 9s
# 220:	learn: 0.8303968	test: 0.8294730	best: 0.8294730 (220)	total: 19.5s	remaining: 1m 8s
# 221:	learn: 0.8304063	test: 0.8295109	best: 0.8295109 (221)	total: 19.6s	remaining: 1m 8s
# 222:	learn: 0.8304917	test: 0.8295109	best: 0.8295109 (221)	total: 19.7s	remaining: 1m 8s
# 223:	learn: 0.8304443	test: 0.8294730	best: 0.8295109 (221)	total: 19.8s	remaining: 1m 8s
# 224:	learn: 0.8304538	test: 0.8295489	best: 0.8295489 (224)	total: 20s	remaining: 1m 8s
# 225:	learn: 0.8305107	test: 0.8293591	best: 0.8295489 (224)	total: 20.1s	remaining: 1m 8s
# 226:	learn: 0.8303968	test: 0.8295109	best: 0.8295489 (224)	total: 20.1s	remaining: 1m 8s
# 227:	learn: 0.8303683	test: 0.8293970	best: 0.8295489 (224)	total: 20.2s	remaining: 1m 8s
# 228:	learn: 0.8304538	test: 0.8293211	best: 0.8295489 (224)	total: 20.3s	remaining: 1m 8s
# 229:	learn: 0.8304633	test: 0.8293211	best: 0.8295489 (224)	total: 20.4s	remaining: 1m 8s
# 230:	learn: 0.8304728	test: 0.8296248	best: 0.8296248 (230)	total: 20.5s	remaining: 1m 8s
# 231:	learn: 0.8304348	test: 0.8293970	best: 0.8296248 (230)	total: 20.6s	remaining: 1m 8s
# 232:	learn: 0.8304348	test: 0.8294350	best: 0.8296248 (230)	total: 20.7s	remaining: 1m 8s
# 233:	learn: 0.8305012	test: 0.8296248	best: 0.8296248 (230)	total: 20.7s	remaining: 1m 7s
# 234:	learn: 0.8306721	test: 0.8297388	best: 0.8297388 (234)	total: 20.8s	remaining: 1m 7s
# 235:	learn: 0.8306531	test: 0.8297767	best: 0.8297767 (235)	total: 20.9s	remaining: 1m 7s
# 236:	learn: 0.8307386	test: 0.8297767	best: 0.8297767 (235)	total: 21s	remaining: 1m 7s
# 237:	learn: 0.8307196	test: 0.8297388	best: 0.8297767 (235)	total: 21s	remaining: 1m 7s
# 238:	learn: 0.8308050	test: 0.8296628	best: 0.8297767 (235)	total: 21.1s	remaining: 1m 7s
# 239:	learn: 0.8309854	test: 0.8298527	best: 0.8298527 (239)	total: 21.2s	remaining: 1m 7s
# 240:	learn: 0.8309664	test: 0.8299666	best: 0.8299666 (240)	total: 21.3s	remaining: 1m 6s
# 241:	learn: 0.8308999	test: 0.8300046	best: 0.8300046 (241)	total: 21.3s	remaining: 1m 6s
# 242:	learn: 0.8309189	test: 0.8301944	best: 0.8301944 (242)	total: 21.5s	remaining: 1m 6s
# 243:	learn: 0.8309094	test: 0.8303083	best: 0.8303083 (243)	total: 21.5s	remaining: 1m 6s
# 244:	learn: 0.8309284	test: 0.8302324	best: 0.8303083 (243)	total: 21.7s	remaining: 1m 6s
# 245:	learn: 0.8309569	test: 0.8303463	best: 0.8303463 (245)	total: 21.7s	remaining: 1m 6s
# 246:	learn: 0.8310898	test: 0.8304222	best: 0.8304222 (246)	total: 21.8s	remaining: 1m 6s
# 247:	learn: 0.8310898	test: 0.8304982	best: 0.8304982 (247)	total: 21.9s	remaining: 1m 6s
# 248:	learn: 0.8311088	test: 0.8305741	best: 0.8305741 (248)	total: 22s	remaining: 1m 6s
# 249:	learn: 0.8311752	test: 0.8306880	best: 0.8306880 (249)	total: 22.1s	remaining: 1m 6s
# 250:	learn: 0.8311183	test: 0.8306880	best: 0.8306880 (249)	total: 22.2s	remaining: 1m 6s
# 251:	learn: 0.8312322	test: 0.8306121	best: 0.8306880 (249)	total: 22.3s	remaining: 1m 6s
# 252:	learn: 0.8313556	test: 0.8306121	best: 0.8306880 (249)	total: 22.4s	remaining: 1m 6s
# 253:	learn: 0.8313176	test: 0.8306501	best: 0.8306880 (249)	total: 22.5s	remaining: 1m 5s
# 254:	learn: 0.8313841	test: 0.8307640	best: 0.8307640 (254)	total: 22.5s	remaining: 1m 5s
# 255:	learn: 0.8313936	test: 0.8309918	best: 0.8309918 (255)	total: 22.6s	remaining: 1m 5s
# 256:	learn: 0.8312512	test: 0.8309538	best: 0.8309918 (255)	total: 22.7s	remaining: 1m 5s
# 257:	learn: 0.8313081	test: 0.8310298	best: 0.8310298 (257)	total: 22.9s	remaining: 1m 5s
# 258:	learn: 0.8313461	test: 0.8309918	best: 0.8310298 (257)	total: 23.2s	remaining: 1m 6s
# 259:	learn: 0.8313936	test: 0.8309918	best: 0.8310298 (257)	total: 23.3s	remaining: 1m 6s
# 260:	learn: 0.8314885	test: 0.8309918	best: 0.8310298 (257)	total: 23.4s	remaining: 1m 6s
# 261:	learn: 0.8314695	test: 0.8310677	best: 0.8310677 (261)	total: 23.6s	remaining: 1m 6s
# 262:	learn: 0.8315075	test: 0.8311817	best: 0.8311817 (262)	total: 23.7s	remaining: 1m 6s
# 263:	learn: 0.8315834	test: 0.8311057	best: 0.8311817 (262)	total: 23.9s	remaining: 1m 6s
# 264:	learn: 0.8315455	test: 0.8311437	best: 0.8311817 (262)	total: 24s	remaining: 1m 6s
# 265:	learn: 0.8315740	test: 0.8310298	best: 0.8311817 (262)	total: 24.2s	remaining: 1m 6s
# 266:	learn: 0.8316024	test: 0.8310298	best: 0.8311817 (262)	total: 24.3s	remaining: 1m 6s
# 267:	learn: 0.8316974	test: 0.8310298	best: 0.8311817 (262)	total: 24.4s	remaining: 1m 6s
# 268:	learn: 0.8317353	test: 0.8311437	best: 0.8311817 (262)	total: 24.6s	remaining: 1m 6s
# 269:	learn: 0.8317923	test: 0.8311817	best: 0.8311817 (262)	total: 24.7s	remaining: 1m 6s
# 270:	learn: 0.8317733	test: 0.8311057	best: 0.8311817 (262)	total: 24.8s	remaining: 1m 6s
# 271:	learn: 0.8318113	test: 0.8311057	best: 0.8311817 (262)	total: 24.9s	remaining: 1m 6s
# 272:	learn: 0.8318398	test: 0.8311057	best: 0.8311817 (262)	total: 25s	remaining: 1m 6s
# 273:	learn: 0.8318493	test: 0.8311437	best: 0.8311817 (262)	total: 25.1s	remaining: 1m 6s
# 274:	learn: 0.8320201	test: 0.8311057	best: 0.8311817 (262)	total: 25.3s	remaining: 1m 6s
# 275:	learn: 0.8319916	test: 0.8311437	best: 0.8311817 (262)	total: 25.4s	remaining: 1m 6s
# 276:	learn: 0.8319822	test: 0.8311057	best: 0.8311817 (262)	total: 25.5s	remaining: 1m 6s
# 277:	learn: 0.8320106	test: 0.8312956	best: 0.8312956 (277)	total: 25.7s	remaining: 1m 6s
# 278:	learn: 0.8320391	test: 0.8311817	best: 0.8312956 (277)	total: 25.8s	remaining: 1m 6s
# 279:	learn: 0.8320201	test: 0.8310677	best: 0.8312956 (277)	total: 25.9s	remaining: 1m 6s
# 280:	learn: 0.8320866	test: 0.8312576	best: 0.8312956 (277)	total: 26.1s	remaining: 1m 6s
# 281:	learn: 0.8321910	test: 0.8315234	best: 0.8315234 (281)	total: 26.2s	remaining: 1m 6s
# 282:	learn: 0.8321530	test: 0.8315234	best: 0.8315234 (281)	total: 26.3s	remaining: 1m 6s
# 283:	learn: 0.8322100	test: 0.8315993	best: 0.8315993 (283)	total: 26.4s	remaining: 1m 6s
# 284:	learn: 0.8322480	test: 0.8315614	best: 0.8315993 (283)	total: 26.6s	remaining: 1m 6s
# 285:	learn: 0.8322954	test: 0.8315614	best: 0.8315993 (283)	total: 26.7s	remaining: 1m 6s
# 286:	learn: 0.8322764	test: 0.8315993	best: 0.8315993 (283)	total: 26.8s	remaining: 1m 6s
# 287:	learn: 0.8323239	test: 0.8315234	best: 0.8315993 (283)	total: 26.9s	remaining: 1m 6s
# 288:	learn: 0.8324188	test: 0.8315234	best: 0.8315993 (283)	total: 27s	remaining: 1m 6s
# 289:	learn: 0.8325233	test: 0.8315993	best: 0.8315993 (283)	total: 27.2s	remaining: 1m 6s
# 290:	learn: 0.8325233	test: 0.8315993	best: 0.8315993 (283)	total: 27.3s	remaining: 1m 6s
# 291:	learn: 0.8324283	test: 0.8313715	best: 0.8315993 (283)	total: 27.3s	remaining: 1m 6s
# 292:	learn: 0.8325233	test: 0.8315234	best: 0.8315993 (283)	total: 27.4s	remaining: 1m 6s
# 293:	learn: 0.8325138	test: 0.8315234	best: 0.8315993 (283)	total: 27.5s	remaining: 1m 6s
# 294:	learn: 0.8326562	test: 0.8315614	best: 0.8315993 (283)	total: 27.7s	remaining: 1m 6s
# 295:	learn: 0.8326657	test: 0.8315614	best: 0.8315993 (283)	total: 27.8s	remaining: 1m 6s
# 296:	learn: 0.8327416	test: 0.8318272	best: 0.8318272 (296)	total: 28s	remaining: 1m 6s
# 297:	learn: 0.8327511	test: 0.8319031	best: 0.8319031 (297)	total: 28s	remaining: 1m 6s
# 298:	learn: 0.8327131	test: 0.8317512	best: 0.8319031 (297)	total: 28.1s	remaining: 1m 5s
# 299:	learn: 0.8327986	test: 0.8316753	best: 0.8319031 (297)	total: 28.2s	remaining: 1m 5s
# 300:	learn: 0.8327986	test: 0.8317132	best: 0.8319031 (297)	total: 28.3s	remaining: 1m 5s
# 301:	learn: 0.8328650	test: 0.8317132	best: 0.8319031 (297)	total: 28.4s	remaining: 1m 5s
# 302:	learn: 0.8329884	test: 0.8319411	best: 0.8319411 (302)	total: 28.5s	remaining: 1m 5s
# 303:	learn: 0.8330074	test: 0.8318651	best: 0.8319411 (302)	total: 28.6s	remaining: 1m 5s
# 304:	learn: 0.8329694	test: 0.8320170	best: 0.8320170 (304)	total: 28.6s	remaining: 1m 5s
# 305:	learn: 0.8329694	test: 0.8320550	best: 0.8320550 (305)	total: 28.7s	remaining: 1m 5s
# 306:	learn: 0.8329789	test: 0.8321309	best: 0.8321309 (306)	total: 28.8s	remaining: 1m 5s
# 307:	learn: 0.8330549	test: 0.8320930	best: 0.8321309 (306)	total: 28.9s	remaining: 1m 4s
# 308:	learn: 0.8330833	test: 0.8320930	best: 0.8321309 (306)	total: 29s	remaining: 1m 4s
# 309:	learn: 0.8331308	test: 0.8320930	best: 0.8321309 (306)	total: 29.1s	remaining: 1m 4s
# 310:	learn: 0.8331403	test: 0.8320930	best: 0.8321309 (306)	total: 29.2s	remaining: 1m 4s
# 311:	learn: 0.8331783	test: 0.8320550	best: 0.8321309 (306)	total: 29.3s	remaining: 1m 4s
# 312:	learn: 0.8331023	test: 0.8320170	best: 0.8321309 (306)	total: 29.4s	remaining: 1m 4s
# 313:	learn: 0.8331688	test: 0.8320170	best: 0.8321309 (306)	total: 29.5s	remaining: 1m 4s
# 314:	learn: 0.8331213	test: 0.8319411	best: 0.8321309 (306)	total: 29.7s	remaining: 1m 4s
# 315:	learn: 0.8331688	test: 0.8319411	best: 0.8321309 (306)	total: 29.8s	remaining: 1m 4s
# 316:	learn: 0.8331878	test: 0.8319411	best: 0.8321309 (306)	total: 29.9s	remaining: 1m 4s
# 317:	learn: 0.8332352	test: 0.8319411	best: 0.8321309 (306)	total: 30s	remaining: 1m 4s
# 318:	learn: 0.8333112	test: 0.8319411	best: 0.8321309 (306)	total: 30.1s	remaining: 1m 4s
# 319:	learn: 0.8333112	test: 0.8318651	best: 0.8321309 (306)	total: 30.2s	remaining: 1m 4s
# 320:	learn: 0.8333112	test: 0.8319790	best: 0.8321309 (306)	total: 30.3s	remaining: 1m 4s
# 321:	learn: 0.8333681	test: 0.8322069	best: 0.8322069 (321)	total: 30.4s	remaining: 1m 4s
# 322:	learn: 0.8334061	test: 0.8319411	best: 0.8322069 (321)	total: 30.5s	remaining: 1m 3s
# 323:	learn: 0.8334251	test: 0.8319411	best: 0.8322069 (321)	total: 30.6s	remaining: 1m 3s
# 324:	learn: 0.8333871	test: 0.8320930	best: 0.8322069 (321)	total: 30.7s	remaining: 1m 3s
# 325:	learn: 0.8333871	test: 0.8320550	best: 0.8322069 (321)	total: 30.8s	remaining: 1m 3s
# 326:	learn: 0.8334726	test: 0.8322448	best: 0.8322448 (326)	total: 30.9s	remaining: 1m 3s
# 327:	learn: 0.8334441	test: 0.8323967	best: 0.8323967 (327)	total: 31s	remaining: 1m 3s
# 328:	learn: 0.8334251	test: 0.8323208	best: 0.8323967 (327)	total: 31.2s	remaining: 1m 3s
# 329:	learn: 0.8334061	test: 0.8323587	best: 0.8323967 (327)	total: 31.3s	remaining: 1m 3s
# 330:	learn: 0.8334821	test: 0.8324347	best: 0.8324347 (330)	total: 31.5s	remaining: 1m 3s
# 331:	learn: 0.8334346	test: 0.8325106	best: 0.8325106 (331)	total: 31.6s	remaining: 1m 3s
# 332:	learn: 0.8334156	test: 0.8324727	best: 0.8325106 (331)	total: 31.6s	remaining: 1m 3s
# 333:	learn: 0.8334441	test: 0.8325486	best: 0.8325486 (333)	total: 31.8s	remaining: 1m 3s
# 334:	learn: 0.8334821	test: 0.8326245	best: 0.8326245 (334)	total: 31.9s	remaining: 1m 3s
# 335:	learn: 0.8335675	test: 0.8326625	best: 0.8326625 (335)	total: 32s	remaining: 1m 3s
# 336:	learn: 0.8335865	test: 0.8326245	best: 0.8326625 (335)	total: 32.1s	remaining: 1m 3s
# 337:	learn: 0.8335580	test: 0.8326245	best: 0.8326625 (335)	total: 32.2s	remaining: 1m 3s
# 338:	learn: 0.8336339	test: 0.8326625	best: 0.8326625 (335)	total: 32.4s	remaining: 1m 3s
# 339:	learn: 0.8336719	test: 0.8327005	best: 0.8327005 (339)	total: 32.5s	remaining: 1m 3s
# 340:	learn: 0.8336529	test: 0.8327764	best: 0.8327764 (340)	total: 32.6s	remaining: 1m 3s
# 341:	learn: 0.8337479	test: 0.8328903	best: 0.8328903 (341)	total: 32.8s	remaining: 1m 3s
# 342:	learn: 0.8336814	test: 0.8327764	best: 0.8328903 (341)	total: 32.9s	remaining: 1m 2s
# 343:	learn: 0.8337289	test: 0.8327385	best: 0.8328903 (341)	total: 33s	remaining: 1m 2s
# 344:	learn: 0.8337669	test: 0.8327005	best: 0.8328903 (341)	total: 33.1s	remaining: 1m 2s
# 345:	learn: 0.8338523	test: 0.8327385	best: 0.8328903 (341)	total: 33.2s	remaining: 1m 2s
# 346:	learn: 0.8338998	test: 0.8326625	best: 0.8328903 (341)	total: 33.3s	remaining: 1m 2s
# 347:	learn: 0.8338713	test: 0.8327385	best: 0.8328903 (341)	total: 33.4s	remaining: 1m 2s
# 348:	learn: 0.8338998	test: 0.8327764	best: 0.8328903 (341)	total: 33.6s	remaining: 1m 2s
# 349:	learn: 0.8339662	test: 0.8325486	best: 0.8328903 (341)	total: 33.7s	remaining: 1m 2s
# 350:	learn: 0.8340137	test: 0.8326625	best: 0.8328903 (341)	total: 33.8s	remaining: 1m 2s
# 351:	learn: 0.8339282	test: 0.8323587	best: 0.8328903 (341)	total: 33.9s	remaining: 1m 2s
# 352:	learn: 0.8340611	test: 0.8323208	best: 0.8328903 (341)	total: 34.1s	remaining: 1m 2s
# 353:	learn: 0.8340611	test: 0.8323587	best: 0.8328903 (341)	total: 34.2s	remaining: 1m 2s
# 354:	learn: 0.8340516	test: 0.8324347	best: 0.8328903 (341)	total: 34.3s	remaining: 1m 2s
# 355:	learn: 0.8340327	test: 0.8324347	best: 0.8328903 (341)	total: 34.4s	remaining: 1m 2s
# 356:	learn: 0.8340896	test: 0.8324727	best: 0.8328903 (341)	total: 34.5s	remaining: 1m 2s
# 357:	learn: 0.8340896	test: 0.8323587	best: 0.8328903 (341)	total: 34.6s	remaining: 1m 2s
# 358:	learn: 0.8341466	test: 0.8323967	best: 0.8328903 (341)	total: 34.8s	remaining: 1m 2s
# 359:	learn: 0.8341751	test: 0.8323208	best: 0.8328903 (341)	total: 34.9s	remaining: 1m 1s
# 360:	learn: 0.8342415	test: 0.8327764	best: 0.8328903 (341)	total: 35s	remaining: 1m 1s
# 361:	learn: 0.8342510	test: 0.8326245	best: 0.8328903 (341)	total: 35.1s	remaining: 1m 1s
# 362:	learn: 0.8342700	test: 0.8325866	best: 0.8328903 (341)	total: 35.2s	remaining: 1m 1s
# 363:	learn: 0.8342890	test: 0.8326245	best: 0.8328903 (341)	total: 35.3s	remaining: 1m 1s
# 364:	learn: 0.8342510	test: 0.8327385	best: 0.8328903 (341)	total: 35.4s	remaining: 1m 1s
# 365:	learn: 0.8341656	test: 0.8327385	best: 0.8328903 (341)	total: 35.5s	remaining: 1m 1s
# 366:	learn: 0.8342510	test: 0.8327005	best: 0.8328903 (341)	total: 35.6s	remaining: 1m 1s
# 367:	learn: 0.8342605	test: 0.8328144	best: 0.8328903 (341)	total: 35.8s	remaining: 1m 1s
# 368:	learn: 0.8343080	test: 0.8328524	best: 0.8328903 (341)	total: 35.9s	remaining: 1m 1s
# 369:	learn: 0.8342985	test: 0.8329283	best: 0.8329283 (369)	total: 36s	remaining: 1m 1s
# 370:	learn: 0.8343080	test: 0.8329663	best: 0.8329663 (370)	total: 36.1s	remaining: 1m 1s
# 371:	learn: 0.8344693	test: 0.8331941	best: 0.8331941 (371)	total: 36.2s	remaining: 1m 1s
# 372:	learn: 0.8344693	test: 0.8332700	best: 0.8332700 (372)	total: 36.3s	remaining: 1m 1s
# 373:	learn: 0.8344788	test: 0.8329663	best: 0.8332700 (372)	total: 36.4s	remaining: 1m
# 374:	learn: 0.8345927	test: 0.8333460	best: 0.8333460 (374)	total: 36.5s	remaining: 1m
# 375:	learn: 0.8347162	test: 0.8331561	best: 0.8333460 (374)	total: 36.6s	remaining: 1m
# 376:	learn: 0.8346782	test: 0.8331941	best: 0.8333460 (374)	total: 36.7s	remaining: 1m
# 377:	learn: 0.8346877	test: 0.8331941	best: 0.8333460 (374)	total: 36.8s	remaining: 1m
# 378:	learn: 0.8346782	test: 0.8331561	best: 0.8333460 (374)	total: 37s	remaining: 1m
# 379:	learn: 0.8346687	test: 0.8333460	best: 0.8333460 (374)	total: 37.1s	remaining: 1m
# 380:	learn: 0.8346782	test: 0.8334219	best: 0.8334219 (380)	total: 37.2s	remaining: 1m
# 381:	learn: 0.8346782	test: 0.8334219	best: 0.8334219 (380)	total: 37.3s	remaining: 1m
# 382:	learn: 0.8346307	test: 0.8333080	best: 0.8334219 (380)	total: 37.4s	remaining: 1m
# 383:	learn: 0.8346402	test: 0.8334219	best: 0.8334219 (380)	total: 37.5s	remaining: 1m
# 384:	learn: 0.8347067	test: 0.8334599	best: 0.8334599 (384)	total: 37.6s	remaining: 1m
# 385:	learn: 0.8347162	test: 0.8333460	best: 0.8334599 (384)	total: 37.7s	remaining: 60s
# 386:	learn: 0.8347162	test: 0.8334979	best: 0.8334979 (386)	total: 37.8s	remaining: 59.9s
# 387:	learn: 0.8347067	test: 0.8334219	best: 0.8334979 (386)	total: 37.9s	remaining: 59.7s
# 388:	learn: 0.8347257	test: 0.8335358	best: 0.8335358 (388)	total: 38s	remaining: 59.7s
# 389:	learn: 0.8347921	test: 0.8332321	best: 0.8335358 (388)	total: 38.1s	remaining: 59.6s
# 390:	learn: 0.8347541	test: 0.8333080	best: 0.8335358 (388)	total: 38.2s	remaining: 59.5s
# 391:	learn: 0.8348016	test: 0.8332700	best: 0.8335358 (388)	total: 38.3s	remaining: 59.4s
# 392:	learn: 0.8348301	test: 0.8333460	best: 0.8335358 (388)	total: 38.4s	remaining: 59.3s
# 393:	learn: 0.8348111	test: 0.8333080	best: 0.8335358 (388)	total: 38.5s	remaining: 59.2s
# 394:	learn: 0.8348870	test: 0.8333080	best: 0.8335358 (388)	total: 38.6s	remaining: 59.1s
# 395:	learn: 0.8349155	test: 0.8334219	best: 0.8335358 (388)	total: 38.8s	remaining: 59.1s
# 396:	learn: 0.8349155	test: 0.8334599	best: 0.8335358 (388)	total: 38.9s	remaining: 59s
# 397:	learn: 0.8349630	test: 0.8333840	best: 0.8335358 (388)	total: 39s	remaining: 58.9s
# 398:	learn: 0.8350009	test: 0.8333840	best: 0.8335358 (388)	total: 39s	remaining: 58.8s
# 399:	learn: 0.8350864	test: 0.8337637	best: 0.8337637 (399)	total: 39.2s	remaining: 58.7s
# 400:	learn: 0.8350959	test: 0.8338016	best: 0.8338016 (400)	total: 39.3s	remaining: 58.6s
# 401:	learn: 0.8351623	test: 0.8337257	best: 0.8338016 (400)	total: 39.3s	remaining: 58.5s
# 402:	learn: 0.8351813	test: 0.8336498	best: 0.8338016 (400)	total: 39.4s	remaining: 58.4s
# 403:	learn: 0.8352003	test: 0.8337257	best: 0.8338016 (400)	total: 39.5s	remaining: 58.3s
# 404:	learn: 0.8351433	test: 0.8334599	best: 0.8338016 (400)	total: 39.6s	remaining: 58.2s
# 405:	learn: 0.8351149	test: 0.8334219	best: 0.8338016 (400)	total: 39.7s	remaining: 58.1s
# 406:	learn: 0.8351339	test: 0.8334979	best: 0.8338016 (400)	total: 39.8s	remaining: 58s
# 407:	learn: 0.8351054	test: 0.8335358	best: 0.8338016 (400)	total: 39.9s	remaining: 57.9s
# 408:	learn: 0.8351528	test: 0.8335358	best: 0.8338016 (400)	total: 40s	remaining: 57.8s
# 409:	learn: 0.8351528	test: 0.8334599	best: 0.8338016 (400)	total: 40.1s	remaining: 57.7s
# 410:	learn: 0.8351908	test: 0.8335358	best: 0.8338016 (400)	total: 40.2s	remaining: 57.6s
# 411:	learn: 0.8352383	test: 0.8336118	best: 0.8338016 (400)	total: 40.3s	remaining: 57.5s
# 412:	learn: 0.8352668	test: 0.8336877	best: 0.8338016 (400)	total: 40.4s	remaining: 57.4s
# 413:	learn: 0.8353332	test: 0.8337257	best: 0.8338016 (400)	total: 40.5s	remaining: 57.3s
# 414:	learn: 0.8353332	test: 0.8336118	best: 0.8338016 (400)	total: 40.6s	remaining: 57.2s
# 415:	learn: 0.8353142	test: 0.8334599	best: 0.8338016 (400)	total: 40.7s	remaining: 57.2s
# 416:	learn: 0.8353712	test: 0.8336118	best: 0.8338016 (400)	total: 40.8s	remaining: 57.1s
# 417:	learn: 0.8354376	test: 0.8336118	best: 0.8338016 (400)	total: 40.9s	remaining: 57s
# 418:	learn: 0.8353807	test: 0.8335358	best: 0.8338016 (400)	total: 41s	remaining: 56.9s
# 419:	learn: 0.8354186	test: 0.8335358	best: 0.8338016 (400)	total: 41.1s	remaining: 56.8s
# 420:	learn: 0.8353997	test: 0.8336118	best: 0.8338016 (400)	total: 41.2s	remaining: 56.7s
# 421:	learn: 0.8353997	test: 0.8335738	best: 0.8338016 (400)	total: 41.3s	remaining: 56.5s
# 422:	learn: 0.8354186	test: 0.8337257	best: 0.8338016 (400)	total: 41.4s	remaining: 56.4s
# 423:	learn: 0.8354376	test: 0.8338396	best: 0.8338396 (423)	total: 41.4s	remaining: 56.3s
# 424:	learn: 0.8354566	test: 0.8339156	best: 0.8339156 (424)	total: 41.5s	remaining: 56.2s
# 425:	learn: 0.8354946	test: 0.8340674	best: 0.8340674 (425)	total: 41.7s	remaining: 56.1s
# 426:	learn: 0.8355705	test: 0.8341813	best: 0.8341813 (426)	total: 41.8s	remaining: 56.1s
# 427:	learn: 0.8355895	test: 0.8340295	best: 0.8341813 (426)	total: 41.9s	remaining: 56s
# 428:	learn: 0.8356180	test: 0.8340295	best: 0.8341813 (426)	total: 42s	remaining: 55.9s
# 429:	learn: 0.8356275	test: 0.8340295	best: 0.8341813 (426)	total: 42s	remaining: 55.7s
# 430:	learn: 0.8355326	test: 0.8338776	best: 0.8341813 (426)	total: 42.1s	remaining: 55.6s
# 431:	learn: 0.8355800	test: 0.8339535	best: 0.8341813 (426)	total: 42.2s	remaining: 55.5s
# 432:	learn: 0.8356370	test: 0.8339915	best: 0.8341813 (426)	total: 42.3s	remaining: 55.4s
# 433:	learn: 0.8356275	test: 0.8339915	best: 0.8341813 (426)	total: 42.5s	remaining: 55.4s
# 434:	learn: 0.8356560	test: 0.8339535	best: 0.8341813 (426)	total: 42.5s	remaining: 55.3s
# 435:	learn: 0.8356465	test: 0.8339535	best: 0.8341813 (426)	total: 42.7s	remaining: 55.2s
# 436:	learn: 0.8356275	test: 0.8339535	best: 0.8341813 (426)	total: 42.8s	remaining: 55.1s
# 437:	learn: 0.8356465	test: 0.8339535	best: 0.8341813 (426)	total: 42.9s	remaining: 55s
# 438:	learn: 0.8356560	test: 0.8338776	best: 0.8341813 (426)	total: 43s	remaining: 54.9s
# 439:	learn: 0.8356370	test: 0.8339156	best: 0.8341813 (426)	total: 43.1s	remaining: 54.8s
# 440:	learn: 0.8356750	test: 0.8339535	best: 0.8341813 (426)	total: 43.2s	remaining: 54.7s
# 441:	learn: 0.8356939	test: 0.8341054	best: 0.8341813 (426)	total: 43.3s	remaining: 54.7s
# 442:	learn: 0.8356655	test: 0.8339156	best: 0.8341813 (426)	total: 43.4s	remaining: 54.6s
# 443:	learn: 0.8357129	test: 0.8339535	best: 0.8341813 (426)	total: 43.5s	remaining: 54.5s
# 444:	learn: 0.8357224	test: 0.8339535	best: 0.8341813 (426)	total: 43.6s	remaining: 54.4s
# 445:	learn: 0.8358648	test: 0.8338776	best: 0.8341813 (426)	total: 43.7s	remaining: 54.3s
# 446:	learn: 0.8357984	test: 0.8340295	best: 0.8341813 (426)	total: 43.8s	remaining: 54.2s
# 447:	learn: 0.8358553	test: 0.8340295	best: 0.8341813 (426)	total: 43.9s	remaining: 54.1s
# 448:	learn: 0.8358648	test: 0.8339156	best: 0.8341813 (426)	total: 44s	remaining: 54s
# 449:	learn: 0.8358743	test: 0.8340674	best: 0.8341813 (426)	total: 44.1s	remaining: 53.9s
# 450:	learn: 0.8359503	test: 0.8340295	best: 0.8341813 (426)	total: 44.2s	remaining: 53.8s
# 451:	learn: 0.8359597	test: 0.8340295	best: 0.8341813 (426)	total: 44.3s	remaining: 53.7s
# 452:	learn: 0.8359597	test: 0.8340295	best: 0.8341813 (426)	total: 44.4s	remaining: 53.6s
# 453:	learn: 0.8358648	test: 0.8339535	best: 0.8341813 (426)	total: 44.5s	remaining: 53.5s
# 454:	learn: 0.8358648	test: 0.8339156	best: 0.8341813 (426)	total: 44.6s	remaining: 53.4s
# 455:	learn: 0.8358838	test: 0.8339915	best: 0.8341813 (426)	total: 44.7s	remaining: 53.3s
# 456:	learn: 0.8359408	test: 0.8339915	best: 0.8341813 (426)	total: 44.8s	remaining: 53.2s
# 457:	learn: 0.8359123	test: 0.8339535	best: 0.8341813 (426)	total: 44.9s	remaining: 53.2s
# 458:	learn: 0.8359123	test: 0.8340674	best: 0.8341813 (426)	total: 45s	remaining: 53.1s
# 459:	learn: 0.8358838	test: 0.8340674	best: 0.8341813 (426)	total: 45.2s	remaining: 53s
# 460:	learn: 0.8358648	test: 0.8340295	best: 0.8341813 (426)	total: 45.3s	remaining: 52.9s
# 461:	learn: 0.8358838	test: 0.8340295	best: 0.8341813 (426)	total: 45.4s	remaining: 52.9s
# 462:	learn: 0.8358838	test: 0.8341813	best: 0.8341813 (426)	total: 45.5s	remaining: 52.8s
# 463:	learn: 0.8358838	test: 0.8341054	best: 0.8341813 (426)	total: 45.6s	remaining: 52.7s
# 464:	learn: 0.8358838	test: 0.8341054	best: 0.8341813 (426)	total: 45.7s	remaining: 52.6s
# 465:	learn: 0.8358648	test: 0.8342953	best: 0.8342953 (465)	total: 45.9s	remaining: 52.5s
# 466:	learn: 0.8358743	test: 0.8342953	best: 0.8342953 (465)	total: 46s	remaining: 52.5s
# 467:	learn: 0.8358933	test: 0.8343332	best: 0.8343332 (467)	total: 46.1s	remaining: 52.4s
# 468:	learn: 0.8358743	test: 0.8342953	best: 0.8343332 (467)	total: 46.2s	remaining: 52.3s
# 469:	learn: 0.8359408	test: 0.8344471	best: 0.8344471 (469)	total: 46.3s	remaining: 52.2s
# 470:	learn: 0.8359218	test: 0.8344851	best: 0.8344851 (470)	total: 46.3s	remaining: 52s
# 471:	learn: 0.8359408	test: 0.8345231	best: 0.8345231 (471)	total: 46.4s	remaining: 51.9s
# 472:	learn: 0.8359218	test: 0.8344851	best: 0.8345231 (471)	total: 46.5s	remaining: 51.8s
# 473:	learn: 0.8359218	test: 0.8343712	best: 0.8345231 (471)	total: 46.6s	remaining: 51.7s
# 474:	learn: 0.8359597	test: 0.8344471	best: 0.8345231 (471)	total: 46.7s	remaining: 51.6s
# 475:	learn: 0.8359503	test: 0.8344471	best: 0.8345231 (471)	total: 46.8s	remaining: 51.5s
# 476:	learn: 0.8359503	test: 0.8344851	best: 0.8345231 (471)	total: 46.9s	remaining: 51.4s
# 477:	learn: 0.8359503	test: 0.8344851	best: 0.8345231 (471)	total: 47s	remaining: 51.3s
# 478:	learn: 0.8359313	test: 0.8345231	best: 0.8345231 (471)	total: 47s	remaining: 51.2s
# 479:	learn: 0.8359503	test: 0.8345231	best: 0.8345231 (471)	total: 47.1s	remaining: 51.1s
# 480:	learn: 0.8359123	test: 0.8344851	best: 0.8345231 (471)	total: 47.3s	remaining: 51s
# 481:	learn: 0.8358933	test: 0.8345990	best: 0.8345990 (481)	total: 47.3s	remaining: 50.9s
# 482:	learn: 0.8358079	test: 0.8345611	best: 0.8345990 (481)	total: 47.4s	remaining: 50.8s
# 483:	learn: 0.8358458	test: 0.8345231	best: 0.8345990 (481)	total: 47.5s	remaining: 50.6s
# 484:	learn: 0.8358743	test: 0.8345231	best: 0.8345990 (481)	total: 47.6s	remaining: 50.5s
# 485:	learn: 0.8358743	test: 0.8345231	best: 0.8345990 (481)	total: 47.7s	remaining: 50.4s
# 486:	learn: 0.8359313	test: 0.8345231	best: 0.8345990 (481)	total: 47.8s	remaining: 50.3s
# 487:	learn: 0.8359503	test: 0.8345611	best: 0.8345990 (481)	total: 47.8s	remaining: 50.2s
# 488:	learn: 0.8360167	test: 0.8345611	best: 0.8345990 (481)	total: 47.9s	remaining: 50.1s
# 489:	learn: 0.8360167	test: 0.8345990	best: 0.8345990 (481)	total: 48s	remaining: 49.9s
# 490:	learn: 0.8360642	test: 0.8346370	best: 0.8346370 (490)	total: 48.1s	remaining: 49.8s
# 491:	learn: 0.8361021	test: 0.8345990	best: 0.8346370 (490)	total: 48.1s	remaining: 49.7s
# 492:	learn: 0.8360927	test: 0.8346750	best: 0.8346750 (492)	total: 48.2s	remaining: 49.6s
# 493:	learn: 0.8361021	test: 0.8345990	best: 0.8346750 (492)	total: 48.3s	remaining: 49.5s
# 494:	learn: 0.8361401	test: 0.8345990	best: 0.8346750 (492)	total: 48.4s	remaining: 49.4s
# 495:	learn: 0.8361211	test: 0.8345990	best: 0.8346750 (492)	total: 48.5s	remaining: 49.3s
# 496:	learn: 0.8361211	test: 0.8347129	best: 0.8347129 (496)	total: 48.6s	remaining: 49.2s
# 497:	learn: 0.8361116	test: 0.8347509	best: 0.8347509 (497)	total: 48.7s	remaining: 49.1s
# 498:	learn: 0.8361306	test: 0.8346750	best: 0.8347509 (497)	total: 48.8s	remaining: 49s
# 499:	learn: 0.8361591	test: 0.8347129	best: 0.8347509 (497)	total: 48.9s	remaining: 48.9s
# 500:	learn: 0.8361401	test: 0.8347129	best: 0.8347509 (497)	total: 48.9s	remaining: 48.7s
# 501:	learn: 0.8361401	test: 0.8347129	best: 0.8347509 (497)	total: 49s	remaining: 48.6s
# 502:	learn: 0.8361591	test: 0.8347509	best: 0.8347509 (497)	total: 49.1s	remaining: 48.5s
# 503:	learn: 0.8361496	test: 0.8347129	best: 0.8347509 (497)	total: 49.1s	remaining: 48.4s
# 504:	learn: 0.8361496	test: 0.8347129	best: 0.8347509 (497)	total: 49.2s	remaining: 48.3s
# 505:	learn: 0.8361496	test: 0.8347509	best: 0.8347509 (497)	total: 49.3s	remaining: 48.2s
# 506:	learn: 0.8361306	test: 0.8346750	best: 0.8347509 (497)	total: 49.4s	remaining: 48s
# 507:	learn: 0.8361876	test: 0.8346750	best: 0.8347509 (497)	total: 49.5s	remaining: 47.9s
# 508:	learn: 0.8361876	test: 0.8346750	best: 0.8347509 (497)	total: 49.5s	remaining: 47.8s
# 509:	learn: 0.8361876	test: 0.8346750	best: 0.8347509 (497)	total: 49.6s	remaining: 47.7s
# 510:	learn: 0.8362256	test: 0.8348648	best: 0.8348648 (510)	total: 49.7s	remaining: 47.6s
# 511:	learn: 0.8362445	test: 0.8349787	best: 0.8349787 (511)	total: 49.8s	remaining: 47.5s
# 512:	learn: 0.8362445	test: 0.8347889	best: 0.8349787 (511)	total: 49.9s	remaining: 47.3s
# 513:	learn: 0.8363395	test: 0.8349028	best: 0.8349787 (511)	total: 50s	remaining: 47.3s
# 514:	learn: 0.8363395	test: 0.8349028	best: 0.8349787 (511)	total: 50.1s	remaining: 47.2s
# 515:	learn: 0.8363395	test: 0.8349028	best: 0.8349787 (511)	total: 50.2s	remaining: 47.1s
# 516:	learn: 0.8363585	test: 0.8349028	best: 0.8349787 (511)	total: 50.3s	remaining: 46.9s
# 517:	learn: 0.8363490	test: 0.8349408	best: 0.8349787 (511)	total: 50.3s	remaining: 46.8s
# 518:	learn: 0.8363680	test: 0.8349787	best: 0.8349787 (511)	total: 50.4s	remaining: 46.7s
# 519:	learn: 0.8363680	test: 0.8349408	best: 0.8349787 (511)	total: 50.5s	remaining: 46.6s
# 520:	learn: 0.8363680	test: 0.8349408	best: 0.8349787 (511)	total: 50.6s	remaining: 46.5s
# 521:	learn: 0.8363774	test: 0.8349408	best: 0.8349787 (511)	total: 50.8s	remaining: 46.5s
# 522:	learn: 0.8363205	test: 0.8348269	best: 0.8349787 (511)	total: 50.9s	remaining: 46.4s
# 523:	learn: 0.8363680	test: 0.8347889	best: 0.8349787 (511)	total: 50.9s	remaining: 46.3s
# 524:	learn: 0.8363015	test: 0.8349028	best: 0.8349787 (511)	total: 51s	remaining: 46.2s
# 525:	learn: 0.8363680	test: 0.8349028	best: 0.8349787 (511)	total: 51.1s	remaining: 46.1s
# 526:	learn: 0.8364629	test: 0.8349408	best: 0.8349787 (511)	total: 51.2s	remaining: 46s
# 527:	learn: 0.8364629	test: 0.8349408	best: 0.8349787 (511)	total: 51.3s	remaining: 45.8s
# 528:	learn: 0.8364724	test: 0.8349408	best: 0.8349787 (511)	total: 51.5s	remaining: 45.8s
# 529:	learn: 0.8364724	test: 0.8349408	best: 0.8349787 (511)	total: 51.7s	remaining: 45.8s
# 530:	learn: 0.8364629	test: 0.8350547	best: 0.8350547 (530)	total: 51.8s	remaining: 45.8s
# 531:	learn: 0.8364439	test: 0.8350926	best: 0.8350926 (531)	total: 52s	remaining: 45.7s
# 532:	learn: 0.8364249	test: 0.8350547	best: 0.8350926 (531)	total: 52.1s	remaining: 45.6s
# 533:	learn: 0.8364249	test: 0.8350547	best: 0.8350926 (531)	total: 52.2s	remaining: 45.5s
# ...
# 1860:	learn: 0.8790773	test: 0.8555589	best: 0.8560526 (1752)	total: 17m 37s	remaining: 1m 19s
# 1861:	learn: 0.8790868	test: 0.8555589	best: 0.8560526 (1752)	total: 17m 38s	remaining: 1m 18s
# 1862:	learn: 0.8790773	test: 0.8555589	best: 0.8560526 (1752)	total: 17m 38s	remaining: 1m 17s
# 1863:	learn: 0.8790773	test: 0.8555589	best: 0.8560526 (1752)	total: 17m 39s	remaining: 1m 17s
# 1864:	learn: 0.8790678	test: 0.8555589	best: 0.8560526 (1752)	total: 17m 40s	remaining: 1m 16s
# 1865:	learn: 0.8790678	test: 0.8555589	best: 0.8560526 (1752)	total: 17m 40s	remaining: 1m 16s
# 1866:	learn: 0.8790678	test: 0.8555589	best: 0.8560526 (1752)	total: 17m 40s	remaining: 1m 15s
# 1867:	learn: 0.8790678	test: 0.8555589	best: 0.8560526 (1752)	total: 17m 40s	remaining: 1m 14s
# 1868:	learn: 0.8790773	test: 0.8555589	best: 0.8560526 (1752)	total: 17m 41s	remaining: 1m 14s
# 1869:	learn: 0.8790868	test: 0.8555589	best: 0.8560526 (1752)	total: 17m 42s	remaining: 1m 13s
# 1870:	learn: 0.8790678	test: 0.8555210	best: 0.8560526 (1752)	total: 17m 42s	remaining: 1m 13s
# 1871:	learn: 0.8790678	test: 0.8555210	best: 0.8560526 (1752)	total: 17m 43s	remaining: 1m 12s
# 1872:	learn: 0.8790678	test: 0.8555210	best: 0.8560526 (1752)	total: 17m 43s	remaining: 1m 12s
# 1873:	learn: 0.8790678	test: 0.8555210	best: 0.8560526 (1752)	total: 17m 43s	remaining: 1m 11s
# 1874:	learn: 0.8790678	test: 0.8555210	best: 0.8560526 (1752)	total: 17m 44s	remaining: 1m 10s
# 1875:	learn: 0.8790773	test: 0.8555210	best: 0.8560526 (1752)	total: 17m 44s	remaining: 1m 10s
# 1876:	learn: 0.8790773	test: 0.8555210	best: 0.8560526 (1752)	total: 17m 45s	remaining: 1m 9s
# 1877:	learn: 0.8790773	test: 0.8555210	best: 0.8560526 (1752)	total: 17m 45s	remaining: 1m 9s
# 1878:	learn: 0.8790963	test: 0.8555589	best: 0.8560526 (1752)	total: 17m 46s	remaining: 1m 8s
# 1879:	learn: 0.8790963	test: 0.8555589	best: 0.8560526 (1752)	total: 17m 47s	remaining: 1m 8s
# 1880:	learn: 0.8791152	test: 0.8555589	best: 0.8560526 (1752)	total: 17m 48s	remaining: 1m 7s
# 1881:	learn: 0.8791152	test: 0.8555589	best: 0.8560526 (1752)	total: 17m 48s	remaining: 1m 6s
# 1882:	learn: 0.8791058	test: 0.8555969	best: 0.8560526 (1752)	total: 17m 49s	remaining: 1m 6s
# 1883:	learn: 0.8791058	test: 0.8555589	best: 0.8560526 (1752)	total: 17m 49s	remaining: 1m 5s
# 1884:	learn: 0.8791152	test: 0.8555589	best: 0.8560526 (1752)	total: 17m 50s	remaining: 1m 5s
# 1885:	learn: 0.8791342	test: 0.8555589	best: 0.8560526 (1752)	total: 17m 50s	remaining: 1m 4s
# 1886:	learn: 0.8791247	test: 0.8555589	best: 0.8560526 (1752)	total: 17m 50s	remaining: 1m 4s
# 1887:	learn: 0.8791247	test: 0.8555210	best: 0.8560526 (1752)	total: 17m 50s	remaining: 1m 3s
# 1888:	learn: 0.8791247	test: 0.8555969	best: 0.8560526 (1752)	total: 17m 50s	remaining: 1m 2s
# 1889:	learn: 0.8791152	test: 0.8555589	best: 0.8560526 (1752)	total: 17m 51s	remaining: 1m 2s
# 1890:	learn: 0.8791152	test: 0.8555589	best: 0.8560526 (1752)	total: 17m 51s	remaining: 1m 1s
# 1891:	learn: 0.8793716	test: 0.8558247	best: 0.8560526 (1752)	total: 17m 52s	remaining: 1m 1s
# 1892:	learn: 0.8794475	test: 0.8562424	best: 0.8562424 (1892)	total: 17m 53s	remaining: 1m
# 1893:	learn: 0.8795234	test: 0.8562424	best: 0.8562424 (1892)	total: 17m 54s	remaining: 1m
# 1894:	learn: 0.8795234	test: 0.8561285	best: 0.8562424 (1892)	total: 17m 54s	remaining: 59.6s
# 1895:	learn: 0.8794855	test: 0.8561665	best: 0.8562424 (1892)	total: 17m 55s	remaining: 59s
# 1896:	learn: 0.8795614	test: 0.8560526	best: 0.8562424 (1892)	total: 17m 56s	remaining: 58.4s
# 1897:	learn: 0.8795424	test: 0.8560526	best: 0.8562424 (1892)	total: 17m 57s	remaining: 57.9s
# 1898:	learn: 0.8795519	test: 0.8559386	best: 0.8562424 (1892)	total: 17m 58s	remaining: 57.3s
# 1899:	learn: 0.8795614	test: 0.8559386	best: 0.8562424 (1892)	total: 17m 58s	remaining: 56.8s
# 1900:	learn: 0.8795614	test: 0.8559007	best: 0.8562424 (1892)	total: 17m 59s	remaining: 56.2s
# 1901:	learn: 0.8795519	test: 0.8559007	best: 0.8562424 (1892)	total: 18m	remaining: 55.7s
# 1902:	learn: 0.8795519	test: 0.8559007	best: 0.8562424 (1892)	total: 18m 1s	remaining: 55.1s
# 1903:	learn: 0.8795804	test: 0.8559007	best: 0.8562424 (1892)	total: 18m 1s	remaining: 54.5s
# 1904:	learn: 0.8795804	test: 0.8559007	best: 0.8562424 (1892)	total: 18m 2s	remaining: 54s
# 1905:	learn: 0.8795424	test: 0.8559007	best: 0.8562424 (1892)	total: 18m 2s	remaining: 53.4s
# 1906:	learn: 0.8795709	test: 0.8559007	best: 0.8562424 (1892)	total: 18m 3s	remaining: 52.8s
# 1907:	learn: 0.8798272	test: 0.8560146	best: 0.8562424 (1892)	total: 18m 4s	remaining: 52.3s
# 1908:	learn: 0.8799032	test: 0.8560905	best: 0.8562424 (1892)	total: 18m 5s	remaining: 51.7s
# 1909:	learn: 0.8798937	test: 0.8560905	best: 0.8562424 (1892)	total: 18m 5s	remaining: 51.2s
# 1910:	learn: 0.8798937	test: 0.8560526	best: 0.8562424 (1892)	total: 18m 6s	remaining: 50.6s
# 1911:	learn: 0.8799032	test: 0.8560526	best: 0.8562424 (1892)	total: 18m 7s	remaining: 50s
# 1912:	learn: 0.8799316	test: 0.8560146	best: 0.8562424 (1892)	total: 18m 8s	remaining: 49.5s
# 1913:	learn: 0.8801120	test: 0.8561665	best: 0.8562424 (1892)	total: 18m 8s	remaining: 48.9s
# 1914:	learn: 0.8801120	test: 0.8562424	best: 0.8562424 (1892)	total: 18m 9s	remaining: 48.4s
# 1915:	learn: 0.8801025	test: 0.8562804	best: 0.8562804 (1915)	total: 18m 10s	remaining: 47.8s
# 1916:	learn: 0.8801120	test: 0.8563183	best: 0.8563183 (1916)	total: 18m 10s	remaining: 47.2s
# 1917:	learn: 0.8801120	test: 0.8563183	best: 0.8563183 (1916)	total: 18m 11s	remaining: 46.6s
# 1918:	learn: 0.8801120	test: 0.8563183	best: 0.8563183 (1916)	total: 18m 11s	remaining: 46.1s
# 1919:	learn: 0.8800835	test: 0.8563563	best: 0.8563563 (1919)	total: 18m 11s	remaining: 45.5s
# 1920:	learn: 0.8800835	test: 0.8563563	best: 0.8563563 (1919)	total: 18m 12s	remaining: 44.9s
# 1921:	learn: 0.8800740	test: 0.8563563	best: 0.8563563 (1919)	total: 18m 12s	remaining: 44.3s
# 1922:	learn: 0.8800740	test: 0.8563563	best: 0.8563563 (1919)	total: 18m 12s	remaining: 43.8s
# 1923:	learn: 0.8800835	test: 0.8563563	best: 0.8563563 (1919)	total: 18m 13s	remaining: 43.2s
# 1924:	learn: 0.8801025	test: 0.8563563	best: 0.8563563 (1919)	total: 18m 13s	remaining: 42.6s
# 1925:	learn: 0.8800930	test: 0.8563563	best: 0.8563563 (1919)	total: 18m 14s	remaining: 42.1s
# 1926:	learn: 0.8800930	test: 0.8563563	best: 0.8563563 (1919)	total: 18m 14s	remaining: 41.5s
# 1927:	learn: 0.8800930	test: 0.8563563	best: 0.8563563 (1919)	total: 18m 14s	remaining: 40.9s
# 1928:	learn: 0.8800930	test: 0.8563563	best: 0.8563563 (1919)	total: 18m 15s	remaining: 40.3s
# 1929:	learn: 0.8800646	test: 0.8562804	best: 0.8563563 (1919)	total: 18m 15s	remaining: 39.7s
# 1930:	learn: 0.8800646	test: 0.8562804	best: 0.8563563 (1919)	total: 18m 16s	remaining: 39.2s
# 1931:	learn: 0.8800646	test: 0.8562804	best: 0.8563563 (1919)	total: 18m 17s	remaining: 38.6s
# 1932:	learn: 0.8800456	test: 0.8563183	best: 0.8563563 (1919)	total: 18m 17s	remaining: 38.1s
# 1933:	learn: 0.8800456	test: 0.8563183	best: 0.8563563 (1919)	total: 18m 18s	remaining: 37.5s
# 1934:	learn: 0.8800456	test: 0.8563183	best: 0.8563563 (1919)	total: 18m 18s	remaining: 36.9s
# 1935:	learn: 0.8800456	test: 0.8563183	best: 0.8563563 (1919)	total: 18m 19s	remaining: 36.4s
# 1936:	learn: 0.8800551	test: 0.8563183	best: 0.8563563 (1919)	total: 18m 19s	remaining: 35.8s
# 1937:	learn: 0.8800551	test: 0.8563183	best: 0.8563563 (1919)	total: 18m 19s	remaining: 35.2s
# 1938:	learn: 0.8800551	test: 0.8563183	best: 0.8563563 (1919)	total: 18m 20s	remaining: 34.6s
# 1939:	learn: 0.8800551	test: 0.8563183	best: 0.8563563 (1919)	total: 18m 20s	remaining: 34s
# 1940:	learn: 0.8800551	test: 0.8563183	best: 0.8563563 (1919)	total: 18m 20s	remaining: 33.4s
# 1941:	learn: 0.8800551	test: 0.8563183	best: 0.8563563 (1919)	total: 18m 20s	remaining: 32.9s
# 1942:	learn: 0.8800646	test: 0.8563183	best: 0.8563563 (1919)	total: 18m 21s	remaining: 32.3s
# 1943:	learn: 0.8800740	test: 0.8563183	best: 0.8563563 (1919)	total: 18m 21s	remaining: 31.7s
# 1944:	learn: 0.8800740	test: 0.8563183	best: 0.8563563 (1919)	total: 18m 22s	remaining: 31.2s
# 1945:	learn: 0.8800740	test: 0.8563183	best: 0.8563563 (1919)	total: 18m 23s	remaining: 30.6s
# 1946:	learn: 0.8801880	test: 0.8563183	best: 0.8563563 (1919)	total: 18m 23s	remaining: 30.1s
# 1947:	learn: 0.8801690	test: 0.8563183	best: 0.8563563 (1919)	total: 18m 24s	remaining: 29.5s
# 1948:	learn: 0.8801785	test: 0.8563183	best: 0.8563563 (1919)	total: 18m 24s	remaining: 28.9s
# 1949:	learn: 0.8801690	test: 0.8563563	best: 0.8563563 (1919)	total: 18m 25s	remaining: 28.3s
# 1950:	learn: 0.8801785	test: 0.8563563	best: 0.8563563 (1919)	total: 18m 26s	remaining: 27.8s
# 1951:	learn: 0.8801785	test: 0.8563563	best: 0.8563563 (1919)	total: 18m 26s	remaining: 27.2s
# 1952:	learn: 0.8801785	test: 0.8563943	best: 0.8563943 (1952)	total: 18m 27s	remaining: 26.7s
# 1953:	learn: 0.8801785	test: 0.8563943	best: 0.8563943 (1952)	total: 18m 28s	remaining: 26.1s
# 1954:	learn: 0.8801785	test: 0.8563943	best: 0.8563943 (1952)	total: 18m 28s	remaining: 25.5s
# 1955:	learn: 0.8801785	test: 0.8563943	best: 0.8563943 (1952)	total: 18m 29s	remaining: 24.9s
# 1956:	learn: 0.8801690	test: 0.8563943	best: 0.8563943 (1952)	total: 18m 29s	remaining: 24.4s
# 1957:	learn: 0.8801690	test: 0.8563943	best: 0.8563943 (1952)	total: 18m 29s	remaining: 23.8s
# 1958:	learn: 0.8801595	test: 0.8563943	best: 0.8563943 (1952)	total: 18m 30s	remaining: 23.2s
# 1959:	learn: 0.8801595	test: 0.8563943	best: 0.8563943 (1952)	total: 18m 31s	remaining: 22.7s
# 1960:	learn: 0.8801595	test: 0.8563943	best: 0.8563943 (1952)	total: 18m 32s	remaining: 22.1s
# 1961:	learn: 0.8801595	test: 0.8563943	best: 0.8563943 (1952)	total: 18m 33s	remaining: 21.6s
# 1962:	learn: 0.8801595	test: 0.8563943	best: 0.8563943 (1952)	total: 18m 33s	remaining: 21s
# 1963:	learn: 0.8801595	test: 0.8563943	best: 0.8563943 (1952)	total: 18m 34s	remaining: 20.4s
# 1964:	learn: 0.8801595	test: 0.8563943	best: 0.8563943 (1952)	total: 18m 34s	remaining: 19.9s
# 1965:	learn: 0.8801690	test: 0.8563943	best: 0.8563943 (1952)	total: 18m 34s	remaining: 19.3s
# 1966:	learn: 0.8801690	test: 0.8563563	best: 0.8563943 (1952)	total: 18m 35s	remaining: 18.7s
# 1967:	learn: 0.8801690	test: 0.8563563	best: 0.8563943 (1952)	total: 18m 35s	remaining: 18.1s
# 1968:	learn: 0.8801690	test: 0.8563563	best: 0.8563943 (1952)	total: 18m 35s	remaining: 17.6s
# 1969:	learn: 0.8801690	test: 0.8563563	best: 0.8563943 (1952)	total: 18m 35s	remaining: 17s
# 1970:	learn: 0.8801595	test: 0.8563943	best: 0.8563943 (1952)	total: 18m 36s	remaining: 16.4s
# 1971:	learn: 0.8801595	test: 0.8563943	best: 0.8563943 (1952)	total: 18m 37s	remaining: 15.9s
# 1972:	learn: 0.8801595	test: 0.8563943	best: 0.8563943 (1952)	total: 18m 37s	remaining: 15.3s
# 1973:	learn: 0.8801595	test: 0.8563943	best: 0.8563943 (1952)	total: 18m 37s	remaining: 14.7s
# 1974:	learn: 0.8801595	test: 0.8563943	best: 0.8563943 (1952)	total: 18m 38s	remaining: 14.2s
# 1975:	learn: 0.8801595	test: 0.8563943	best: 0.8563943 (1952)	total: 18m 38s	remaining: 13.6s
# 1976:	learn: 0.8801595	test: 0.8563943	best: 0.8563943 (1952)	total: 18m 38s	remaining: 13s
# 1977:	learn: 0.8801595	test: 0.8563943	best: 0.8563943 (1952)	total: 18m 38s	remaining: 12.4s
# 1978:	learn: 0.8801595	test: 0.8563943	best: 0.8563943 (1952)	total: 18m 38s	remaining: 11.9s
# 1979:	learn: 0.8801595	test: 0.8563943	best: 0.8563943 (1952)	total: 18m 38s	remaining: 11.3s
# 1980:	learn: 0.8801595	test: 0.8563943	best: 0.8563943 (1952)	total: 18m 38s	remaining: 10.7s
# 1981:	learn: 0.8802639	test: 0.8565462	best: 0.8565462 (1981)	total: 18m 39s	remaining: 10.2s
# 1982:	learn: 0.8802639	test: 0.8565462	best: 0.8565462 (1981)	total: 18m 40s	remaining: 9.6s
# 1983:	learn: 0.8802544	test: 0.8565462	best: 0.8565462 (1981)	total: 18m 40s	remaining: 9.04s
# 1984:	learn: 0.8802639	test: 0.8565462	best: 0.8565462 (1981)	total: 18m 41s	remaining: 8.47s
# 1985:	learn: 0.8802544	test: 0.8565082	best: 0.8565462 (1981)	total: 18m 41s	remaining: 7.91s
# 1986:	learn: 0.8802354	test: 0.8564702	best: 0.8565462 (1981)	total: 18m 42s	remaining: 7.34s
# 1987:	learn: 0.8802354	test: 0.8564702	best: 0.8565462 (1981)	total: 18m 43s	remaining: 6.78s
# 1988:	learn: 0.8802829	test: 0.8564323	best: 0.8565462 (1981)	total: 18m 44s	remaining: 6.22s
# 1989:	learn: 0.8802924	test: 0.8564323	best: 0.8565462 (1981)	total: 18m 45s	remaining: 5.65s
# 1990:	learn: 0.8802924	test: 0.8563563	best: 0.8565462 (1981)	total: 18m 45s	remaining: 5.09s
# 1991:	learn: 0.8803114	test: 0.8563563	best: 0.8565462 (1981)	total: 18m 46s	remaining: 4.52s
# 1992:	learn: 0.8803019	test: 0.8563563	best: 0.8565462 (1981)	total: 18m 47s	remaining: 3.96s
# 1993:	learn: 0.8802829	test: 0.8563943	best: 0.8565462 (1981)	total: 18m 48s	remaining: 3.39s
# 1994:	learn: 0.8803114	test: 0.8564323	best: 0.8565462 (1981)	total: 18m 48s	remaining: 2.83s
# 1995:	learn: 0.8803209	test: 0.8564323	best: 0.8565462 (1981)	total: 18m 49s	remaining: 2.26s
# 1996:	learn: 0.8803019	test: 0.8564323	best: 0.8565462 (1981)	total: 18m 50s	remaining: 1.7s
# 1997:	learn: 0.8803209	test: 0.8564702	best: 0.8565462 (1981)	total: 18m 51s	remaining: 1.13s
# 1998:	learn: 0.8803209	test: 0.8564702	best: 0.8565462 (1981)	total: 18m 52s	remaining: 566ms
# 1999:	learn: 0.8803019	test: 0.8564702	best: 0.8565462 (1981)	total: 18m 52s	remaining: 0us
# bestTest = 0.8565461725
# bestIteration = 1981
# Training on fold [0/3]
# ---------------------------------------------------------------------------
# CatBoostError                             Traceback (most recent call last)
# Cell In [50], line 18
#       1 model = catboost.CatBoostClassifier(
#       2     loss_function="Logloss",
#       3     random_seed=42,
#    (...)
#       9     train_dir="./models/v12",
#      10 )
#      12 param_grid = {
#      13     "depth": [4, 6, 8, 10],
#      14     "learning_rate": [0.05, 0.1],
#      15     "iterations": [1000, 2000],
#      16 }
# ---> 18 model.grid_search(
#      19     param_grid,
#      20     train_pool,
#      21     verbose=0,
#      22     plot=True,
#      23     plot_file="models/v12/grid_search.info",
#      24 )
#
# File c:\Program Files\Python310\lib\site-packages\catboost\core.py:4211, in CatBoost.grid_search(self, param_grid, X, y, cv, partition_random_seed, calc_cv_statistics, search_by_train_test_split, refit, shuffle, stratified, train_size, verbose, plot, plot_file, log_cout, log_cerr)
#    4208         if not isinstance(grid[key], Iterable):
#    4209             raise TypeError('Parameter grid value is not iterable (key={!r}, value={!r})'.format(key, grid[key]))
# -> 4211 return self._tune_hyperparams(
#    4212     param_grid=param_grid, X=X, y=y, cv=cv, n_iter=-1,
#    4213     partition_random_seed=partition_random_seed, calc_cv_statistics=calc_cv_statistics,
#    4214     search_by_train_test_split=search_by_train_test_split, refit=refit, shuffle=shuffle,
#    4215     stratified=stratified, train_size=train_size, verbose=verbose, plot=plot, plot_file=plot_file,
#    4216     log_cout=log_cout, log_cerr=log_cerr,
#    4217 )
#
# File c:\Program Files\Python310\lib\site-packages\catboost\core.py:4100, in CatBoost._tune_hyperparams(self, param_grid, X, y, cv, n_iter, partition_random_seed, calc_cv_statistics, search_by_train_test_split, refit, shuffle, stratified, train_size, verbose, plot, plot_file, log_cout, log_cerr)
#    4097     stratified = isinstance(loss_function, STRING_TYPES) and is_cv_stratified_objective(loss_function)
#    4099 with plot_wrapper(plot, plot_file, 'Hyperparameters search plot', [_get_train_dir(params)]):
# -> 4100     cv_result = self._object._tune_hyperparams(
#    4101         param_grid, train_params["train_pool"], params, n_iter,
#    4102         fold_count, partition_random_seed, shuffle, stratified, train_size,
#    4103         search_by_train_test_split, calc_cv_statistics, custom_folds, verbose
#    4104     )
#    4106 if refit:
#    4107     assert not self.is_fitted()
#
# File _catboost.pyx:5524, in _catboost._CatBoost._tune_hyperparams()
#
# File _catboost.pyx:5562, in _catboost._CatBoost._tune_hyperparams()
#
# CatBoostError: catboost/private/libs/feature_estimator/text_feature_estimators.cpp:89: Dictionary size is 0, check out data or try to decrease occurrence_lower_bound parameter

# %%
model.save_model("models/v12/best.cbm")

# %%
preds = model.predict(kaggle_pool, task_type="GPU", devices="0")

# %%
output = pd.DataFrame({"ID": kaggle_data["challenge_id"], "Prediction": preds})
output.to_csv("models/v12/predictions-v12.csv", index=False)
